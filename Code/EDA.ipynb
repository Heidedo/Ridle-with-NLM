# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# Here we focus on some data statistics that we can derive from our previous data cleaning, such as finding the most common words for a specific movie or the size of the vocabulary that is used to describe the movie. We do this step to find out if the data cleaning process worked fine or if there are still words that doesn't make any sense. For example if the word cloud shows us that "one" is a commonly used word for a specific movie, we might have to do some more data cleaning and remove unnecessary words so we can get the best results for our Natural Language Model.

# %%
import pandas as pd
# in anaconda prompt: conda install -c conda-forge wordcloud
from wordcloud import WordCloud
from collections import Counter
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer

# %%
data = pd.read_pickle('Songs_DBpedia_DTM.pkl')
data = data.transpose() # for easier aggregation
data.head()
# Out:
#               '97_Bonnie_&_Clyde  'Cuz_I_Can_(Pink_song)  \
# abbey                          0                       0
# abbreviation                   0                       0
# abolition                      0                       0
# absent                         0                       0
# academy                        0                       0
#
#               'Round_Midnight_(song)  'S_Wonderful  \
# abbey                              0             0
# abbreviation                       0             0
# abolition                          0             0
# absent                             0             0
# academy                            0             0
#
#               'The_Half_of_It,_Dearie'_Blues  'Till_I_Collapse  \
# abbey                                      0                 0
# abbreviation                               0                 0
# abolition                                  0                 0
# absent                                     0                 0
# academy                                    0                 0
#
#               'Tis_Harry_I'm_Plannin'_to_Marry  'n_Beetje  't_Is_Genoeg  \
# abbey                                        0          0             0
# abbreviation                                 0          0             0
# abolition                                    0          0             0
# absent                                       0          0             0
# academy                                      0          0             0
#
#               't_Is_OK  ...  A_Day_in_the_Life_of_a_Tree  \
# abbey                0  ...                            0
# abbreviation         0  ...                            0
# abolition            0  ...                            0
# absent               0  ...                            0
# academy              0  ...                            0
#
#               A_Fellow_Needs_a_Girl  A_Great_Day_for_Freedom  A_Guy_Is_a_Guy  \
# abbey                             0                        0               0
# abbreviation                      0                        0               0
# abolition                         0                        0               0
# absent                            0                        0               0
# academy                           0                        0               0
#
#               A_Guy_Like_You  A_Hard_Rain's_a-Gonna_Fall  A_Kinder_Eye  \
# abbey                      0                           0             0
# abbreviation               0                           0             0
# abolition                  0                           0             0
# absent                     0                           0             0
# academy                    0                           0             0
#
#               A_Little_Bit_Longer_(song)  A_Love_That_Will_Never_Grow_Old  \
# abbey                                  0                                0
# abbreviation                           0                                0
# abolition                              0                                0
# absent                                 0                                0
# academy                                0                                1
#
#               A_Man_Without_Love_(Kenneth_McKellar_song)
# abbey                                                  0
# abbreviation                                           0
# abolition                                              0
# absent                                                 0
# academy                                                0
#
# [5 rows x 100 columns]

# %%
#top 15 words in each summary
top_dict = {}
for c in data.columns:
    top = data[c].sort_values(ascending=False).head(30)
    top_dict[c]= list(zip(top.index, top.values))

top_dict
# Out:
# {"'97_Bonnie_&_Clyde": [('song', 5),
#   ('shady', 3),
#   ('slim', 3),
#   ('kim', 2),
#   ('daughter', 2),
#   ('dark', 1),
#   ('throw', 1),
#   ('pier', 1),
#   ('sea', 1),
#   ('seat', 1),
#   ('dada', 1),
#   ('whilst', 1),
#   ('covered', 1),
#   ('rapper', 1),
#   ('album', 1),
#   ('wife', 1),
#   ('baby', 1),
#   ('couple', 1),
#   ('just', 1),
#   ('fashion', 1),
#   ('little', 1),
#   ('taking', 1),
#   ('strange', 1),
#   ('ex', 1),
#   ('undertone', 1),
#   ('like', 1),
#   ('going', 1),
#   ('let', 1),
#   ('car', 1),
#   ('strap', 1)],
#  "'Cuz_I_Can_(Pink_song)": [('album', 3),
#   ('song', 1),
#   ('dead', 1),
#   ('pink', 1),
#   ('single', 1),
#   ('written', 1),
#   ('martin', 1),
#   ('promotional', 1),
#   ('fourth', 1),
#   ('abbey', 0),
#   ('pollution', 0),
#   ('polish', 0),
#   ('police', 0),
#   ('poco', 0),
#   ('player', 0),
#   ('pleasure', 0),
#   ('pope', 0),
#   ('play', 0),
#   ('platinum', 0),
#   ('place', 0),
#   ('pipe', 0),
#   ('piggy', 0),
#   ('pierrot', 0),
#   ('pop', 0),
#   ('positive', 0),
#   ('popular', 0),
#   ('predominantly', 0),
#   ('prince', 0),
#   ('primarily', 0),
#   ('previously', 0)],
#  "'Round_Midnight_(song)": [('jazz', 3),
#   ('midnight', 1),
#   ('variety', 1),
#   ('pianist', 1),
#   ('quintet', 1),
#   ('hall', 1),
#   ('quickly', 1),
#   ('wide', 1),
#   ('standard', 1),
#   ('monk', 1),
#   ('musician', 1),
#   ('fame', 1),
#   ('version', 1),
#   ('added', 1),
#   ('round', 1),
#   ('composition', 1),
#   ('composed', 1),
#   ('posthumously', 0),
#   ('power', 0),
#   ('pipe', 0),
#   ('place', 0),
#   ('platinum', 0),
#   ('primarily', 0),
#   ('play', 0),
#   ('player', 0),
#   ('previously', 0),
#   ('previous', 0),
#   ('pleasure', 0),
#   ('pretty', 0),
#   ('poco', 0)],
#  "'S_Wonderful": [('song', 3),
#   ('especially', 1),
#   ('broadway', 1),
#   ('stage', 1),
#   ('jazz', 1),
#   ('standard', 1),
#   ('frank', 1),
#   ('popular', 1),
#   ('composed', 1),
#   ('musical', 1),
#   ('written', 1),
#   ('funny', 1),
#   ('year', 1),
#   ('considered', 1),
#   ('successful', 1),
#   ('face', 1),
#   ('previous', 1),
#   ('wonderful', 1),
#   ('police', 0),
#   ('poco', 0),
#   ('pleasure', 0),
#   ('place', 0),
#   ('player', 0),
#   ('play', 0),
#   ('platinum', 0),
#   ('pollution', 0),
#   ('pipe', 0),
#   ('pink', 0),
#   ('piggy', 0),
#   ('polish', 0)],
#  "'The_Half_of_It,_Dearie'_Blues": [('lady', 1),
#   ('musical', 1),
#   ('good', 1),
#   ('song', 1),
#   ('half', 1),
#   ('dearie', 1),
#   ('blues', 1),
#   ('composed', 1),
#   ('piggy', 0),
#   ('pink', 0),
#   ('pipe', 0),
#   ('place', 0),
#   ('pop', 0),
#   ('play', 0),
#   ('player', 0),
#   ('pleasure', 0),
#   ('poco', 0),
#   ('pierrot', 0),
#   ('police', 0),
#   ('polish', 0),
#   ('pollution', 0),
#   ('platinum', 0),
#   ('popular', 0),
#   ('pope', 0),
#   ('piece', 0),
#   ('prince', 0),
#   ('primarily', 0),
#   ('previously', 0),
#   ('previous', 0),
#   ('pretty', 0)],
#  "'Till_I_Collapse": [('rapper', 2),
#   ('song', 2),
#   ('album', 2),
#   ('chart', 1),
#   ('fourth', 1),
#   ('hook', 1),
#   ('despite', 1),
#   ('track', 1),
#   ('billion', 1),
#   ('numerous', 1),
#   ('collapse', 1),
#   ('studio', 1),
#   ('till', 1),
#   ('single', 1),
#   ('times', 1),
#   ('player', 0),
#   ('poco', 0),
#   ('pleasure', 0),
#   ('abbey', 0),
#   ('police', 0),
#   ('platinum', 0),
#   ('place', 0),
#   ('pipe', 0),
#   ('pink', 0),
#   ('piggy', 0),
#   ('play', 0),
#   ('pop', 0),
#   ('polish', 0),
#   ('posthumously', 0),
#   ('pretty', 0)],
#  "'Tis_Harry_I'm_Plannin'_to_Marry": [('song', 2),
#   ('sung', 2),
#   ('film', 2),
#   ('garter', 1),
#   ('sammy', 1),
#   ('jane', 1),
#   ('finally', 1),
#   ('near', 1),
#   ('times', 1),
#   ('end', 1),
#   ('musical', 1),
#   ('brown', 1),
#   ('marry', 1),
#   ('music', 1),
#   ('hit', 1),
#   ('featured', 1),
#   ('popular', 1),
#   ('included', 1),
#   ('fain', 1),
#   ('character', 1),
#   ('harry', 1),
#   ('golden', 1),
#   ('dressing', 1),
#   ('partly', 1),
#   ('calamity', 1),
#   ('peace', 0),
#   ('pollution', 0),
#   ('polish', 0),
#   ('pair', 0),
#   ('police', 0)],
#  "'n_Beetje": [('song', 7),
#   ('dutch', 3),
#   ('faithful', 2),
#   ('bit', 2),
#   ('contest', 2),
#   ('little', 2),
#   ('previous', 2),
#   ('pronunciation', 1),
#   ('poco', 1),
#   ('close', 1),
#   ('unusual', 1),
#   ('preceding', 1),
#   ('television', 1),
#   ('following', 1),
#   ('lover', 1),
#   ('love', 1),
#   ('ami', 1),
#   ('perspective', 1),
#   ('said', 1),
#   ('second', 1),
#   ('wat', 1),
#   ('victory', 1),
#   ('night', 1),
#   ('music', 1),
#   ('field', 1),
#   ('voting', 1),
#   ('sang', 1),
#   ('fifth', 1),
#   ('pierrot', 1),
#   ('entirely', 1)],
#  "'t_Is_Genoeg": [('song', 5),
#   ('sung', 2),
#   ('contest', 2),
#   ('entry', 2),
#   ('lover', 2),
#   ('love', 1),
#   ('night', 1),
#   ('normally', 1),
#   ('perspective', 1),
#   ('happiness', 1),
#   ('en', 1),
#   ('relationship', 1),
#   ('woman', 1),
#   ('pronounced', 1),
#   ('het', 1),
#   ('make', 1),
#   ('received', 1),
#   ('dutch', 1),
#   ('filippo', 1),
#   ('close', 1),
#   ('belong', 1),
#   ('outlook', 1),
#   ('field', 1),
#   ('does', 1),
#   ('voting', 1),
#   ('singer', 1),
#   ('unfaithful', 1),
#   ('singing', 1),
#   ('infidelity', 1),
#   ('preceding', 1)],
#  "'t_Is_OK": [('song', 7),
#   ('dutch', 5),
#   ('contest', 3),
#   ('harmony', 2),
#   ('entry', 2),
#   ('happy', 2),
#   ('field', 1),
#   ('eleventh', 1),
#   ('following', 1),
#   ('received', 1),
#   ('brighten', 1),
#   ('jean', 1),
#   ('number', 1),
#   ('night', 1),
#   ('eddy', 1),
#   ('close', 1),
#   ('colorado', 1),
#   ('winning', 1),
#   ('voting', 1),
#   ('group', 1),
#   ('version', 1),
#   ('vie', 1),
#   ('composed', 1),
#   ('chanter', 1),
#   ('previously', 1),
#   ('sing', 1),
#   ('trio', 1),
#   ('minimal', 1),
#   ('written', 1),
#   ('original', 1)],
#  '(At_Your_Best)_You_Are_Love': [('originally', 2),
#   ('hit', 1),
#   ('best', 1),
#   ('song', 1),
#   ('radio', 1),
#   ('mother', 1),
#   ('love', 1),
#   ('pipe', 0),
#   ('place', 0),
#   ('platinum', 0),
#   ('play', 0),
#   ('pope', 0),
#   ('pink', 0),
#   ('player', 0),
#   ('pleasure', 0),
#   ('poco', 0),
#   ('piggy', 0),
#   ('police', 0),
#   ('polish', 0),
#   ('pollution', 0),
#   ('pop', 0),
#   ('abbey', 0),
#   ('pier', 0),
#   ('popular', 0),
#   ('prince', 0),
#   ('primarily', 0),
#   ('previously', 0),
#   ('previous', 0),
#   ('pretty', 0),
#   ('present', 0)],
#  '(Drop_Dead)_Beautiful': [('album', 10),
#   ('singles', 3),
#   ('brazil', 2),
#   ('second', 2),
#   ('peaked', 2),
#   ('united', 2),
#   ('seventh', 2),
#   ('fourth', 2),
#   ('billboard', 2),
#   ('criminal', 2),
#   ('tour', 2),
#   ('consecutive', 2),
#   ('music', 2),
#   ('successful', 1),
#   ('studio', 1),
#   ('style', 1),
#   ('canada', 1),
#   ('certified', 1),
#   ('generally', 1),
#   ('starring', 1),
#   ('circus', 1),
#   ('orbit', 1),
#   ('leg', 1),
#   ('number', 1),
#   ('television', 1),
#   ('hold', 1),
#   ('till', 1),
#   ('musically', 1),
#   ('hot', 1),
#   ('travis', 1)],
#  '(Evening)_Time_to_Get_Away': [('time', 4),
#   ('album', 4),
#   ('original', 4),
#   ('away', 3),
#   ('song', 3),
#   ('lodge', 3),
#   ('days', 3),
#   ('future', 3),
#   ('entire', 3),
#   ('evening', 3),
#   ('afternoon', 2),
#   ('track', 2),
#   ('day', 2),
#   ('bridge', 2),
#   ('written', 2),
#   ('forever', 2),
#   ('play', 1),
#   ('hayward', 1),
#   ('master', 1),
#   ('satin', 1),
#   ('nights', 1),
#   ('blues', 1),
#   ('title', 1),
#   ('classic', 1),
#   ('excerpt', 1),
#   ('home', 1),
#   ('band', 1),
#   ('unlisted', 1),
#   ('featured', 1),
#   ('minute', 1)],
#  '(Every_Time_I_Turn_Around)_Back_in_Love_Again': [('number', 4),
#   ('love', 3),
#   ('hit', 3),
#   ('spent', 2),
#   ('song', 2),
#   ('pop', 2),
#   ('singles', 2),
#   ('chart', 2),
#   ('gold', 1),
#   ('time', 1),
#   ('record', 1),
#   ('album', 1),
#   ('billboard', 1),
#   ('peaking', 1),
#   ('biggest', 1),
#   ('grey', 1),
#   ('band', 1),
#   ('turn', 1),
#   ('lead', 1),
#   ('fall', 1),
#   ('written', 1),
#   ('single', 1),
#   ('major', 1),
#   ('hot', 1),
#   ('popularity', 0),
#   ('prelude', 0),
#   ('piggy', 0),
#   ('posthumous', 0),
#   ('pink', 0),
#   ('pipe', 0)],
#  "(Everybody's_Waitin'_for)_The_Man_with_the_Bag": [('kay', 2),
#   ('man', 2),
#   ('popular', 2),
#   ('dudley', 2),
#   ('song', 2),
#   ('bag', 2),
#   ('husband', 1),
#   ('regularly', 1),
#   ('television', 1),
#   ('people', 1),
#   ('early', 1),
#   ('list', 1),
#   ('reference', 1),
#   ('credit', 1),
#   ('took', 1),
#   ('club', 1),
#   ('special', 1),
#   ('brought', 1),
#   ('time', 1),
#   ('originally', 1),
#   ('written', 1),
#   ('extra', 1),
#   ('sleigh', 1),
#   ('company', 1),
#   ('post', 0),
#   ('pleasure', 0),
#   ('present', 0),
#   ('player', 0),
#   ('play', 0),
#   ('platinum', 0)],
#  '(Ghost)_Riders_in_the_Sky:_A_Cowboy_Legend': [('ghost', 3),
#   ('song', 3),
#   ('sky', 3),
#   ('legend', 2),
#   ('cowboy', 2),
#   ('title', 2),
#   ('written', 2),
#   ('western', 2),
#   ('chose', 1),
#   ('television', 1),
#   ('pop', 1),
#   ('number', 1),
#   ('code', 1),
#   ('film', 1),
#   ('actor', 1),
#   ('crossover', 1),
#   ('time', 1),
#   ('successful', 1),
#   ('poco', 0),
#   ('pipe', 0),
#   ('place', 0),
#   ('pink', 0),
#   ('piggy', 0),
#   ('platinum', 0),
#   ('play', 0),
#   ('pierrot', 0),
#   ('player', 0),
#   ('pier', 0),
#   ('pleasure', 0),
#   ('abbey', 0)],
#  "(I'd_Like_to_Get_You_on_a)_Slow_Boat_to_China": [('song', 6),
#   ('album', 3),
#   ('frank', 3),
#   ('dove', 2),
#   ('rosemary', 2),
#   ('biggest', 1),
#   ('bing', 1),
#   ('honor', 1),
#   ('ford', 1),
#   ('slow', 1),
#   ('meeting', 1),
#   ('china', 1),
#   ('version', 1),
#   ('popular', 1),
#   ('standard', 1),
#   ('hit', 1),
#   ('jimmy', 1),
#   ('sang', 1),
#   ('pop', 1),
#   ('episode', 1),
#   ('piggy', 1),
#   ('songbook', 1),
#   ('official', 1),
#   ('boat', 1),
#   ('duet', 1),
#   ('domino', 1),
#   ('singles', 1),
#   ('peaking', 1),
#   ('actor', 1),
#   ('barry', 1)],
#  "(I'll_Be_with_You)_In_Apple_Blossom_Time": [('song', 2),
#   ('ill', 1),
#   ('blossom', 1),
#   ('popular', 1),
#   ('time', 1),
#   ('apple', 1),
#   ('lyricist', 1),
#   ('written', 1),
#   ('play', 0),
#   ('police', 0),
#   ('poco', 0),
#   ('pleasure', 0),
#   ('player', 0),
#   ('pipe', 0),
#   ('platinum', 0),
#   ('place', 0),
#   ('pollution', 0),
#   ('pink', 0),
#   ('piggy', 0),
#   ('pierrot', 0),
#   ('pier', 0),
#   ('piece', 0),
#   ('polish', 0),
#   ('pope', 0),
#   ('pop', 0),
#   ('predominantly', 0),
#   ('prince', 0),
#   ('primarily', 0),
#   ('previously', 0),
#   ('previous', 0)],
#  "(I'm_Not_Your)_Steppin'_Stone": [('major', 8),
#   ('song', 2),
#   ('cut', 1),
#   ('rock', 1),
#   ('hart', 1),
#   ('bobby', 1),
#   ('simple', 1),
#   ('tommy', 1),
#   ('musically', 1),
#   ('chord', 1),
#   ('bridge', 1),
#   ('album', 1),
#   ('verse', 1),
#   ('stone', 1),
#   ('time', 1),
#   ('revere', 1),
#   ('written', 1),
#   ('ride', 1),
#   ('progression', 1),
#   ('midnight', 1),
#   ('power', 0),
#   ('present', 0),
#   ('play', 0),
#   ('platinum', 0),
#   ('place', 0),
#   ('pipe', 0),
#   ('pink', 0),
#   ('pretty', 0),
#   ('player', 0),
#   ('piggy', 0)],
#  "(I_Can't_Make_It)_Another_Day": [('day', 6),
#   ('song', 5),
#   ('album', 4),
#   ('leak', 3),
#   ('track', 2),
#   ('make', 2),
#   ('later', 2),
#   ('unofficially', 1),
#   ('version', 1),
#   ('music', 1),
#   ('initially', 1),
#   ('times', 1),
#   ('posthumous', 1),
#   ('artist', 1),
#   ('storm', 1),
#   ('stated', 1),
#   ('place', 1),
#   ('final', 1),
#   ('collaboration', 1),
#   ('snippet', 1),
#   ('featured', 1),
#   ('successful', 1),
#   ('composed', 1),
#   ('posthumously', 1),
#   ('entertainment', 1),
#   ('did', 1),
#   ('removing', 1),
#   ('despite', 1),
#   ('release', 1),
#   ('recording', 1)],
#  '(I_Love_You)_For_Sentimental_Reasons': [('song', 4),
#   ('best', 4),
#   ('member', 4),
#   ('founding', 3),
#   ('brown', 2),
#   ('music', 1),
#   ('vocalist', 1),
#   ('pat', 1),
#   ('company', 1),
#   ('list', 1),
#   ('popular', 1),
#   ('manor', 1),
#   ('group', 1),
#   ('ivory', 1),
#   ('joe', 1),
#   ('king', 1),
#   ('love', 1),
#   ('quartet', 1),
#   ('creation', 1),
#   ('ink', 1),
#   ('autobiography', 1),
#   ('late', 1),
#   ('sentimental', 1),
#   ('lead', 1),
#   ('respectively', 1),
#   ('written', 1),
#   ('label', 1),
#   ('wrote', 1),
#   ('later', 1),
#   ('pleasure', 0)],
#  "(If_You_Can't_Sing_It)_You'll_Have_to_Swing_It_(Mr._Paganini)": [('song', 3),
#   ('cole', 2),
#   ('tribute', 2),
#   ('lady', 1),
#   ('sam', 1),
#   ('live', 1),
#   ('album', 1),
#   ('mark', 1),
#   ('birthday', 1),
#   ('associated', 1),
#   ('springboard', 1),
#   ('love', 1),
#   ('fixture', 1),
#   ('firm', 1),
#   ('signature', 1),
#   ('scat', 1),
#   ('providing', 1),
#   ('june', 1),
#   ('chaka', 1),
#   ('concert', 1),
#   ('written', 1),
#   ('strongly', 1),
#   ('sing', 1),
#   ('swing', 1),
#   ('platinum', 0),
#   ('place', 0),
#   ('preceding', 0),
#   ('pretty', 0),
#   ('play', 0),
#   ('previous', 0)],
#  '(Love_Is)_The_Tender_Trap': [('song', 3),
#   ('film', 2),
#   ('love', 2),
#   ('trap', 2),
#   ('frank', 2),
#   ('tender', 2),
#   ('united', 1),
#   ('peaking', 1),
#   ('award', 1),
#   ('popular', 1),
#   ('major', 1),
#   ('hit', 1),
#   ('version', 1),
#   ('separately', 1),
#   ('jimmy', 1),
#   ('lost', 1),
#   ('thing', 1),
#   ('sammy', 1),
#   ('van', 1),
#   ('nominated', 1),
#   ('sing', 1),
#   ('kingdom', 1),
#   ('best', 1),
#   ('academy', 1),
#   ('written', 1),
#   ('composed', 1),
#   ('original', 1),
#   ('posse', 0),
#   ('player', 0),
#   ('predominantly', 0)],
#  '(Mama)_He_Treats_Your_Daughter_Mean': [('chart', 3),
#   ('pop', 2),
#   ('brown', 2),
#   ('song', 2),
#   ('mean', 1),
#   ('lance', 1),
#   ('ruth', 1),
#   ('hit', 1),
#   ('billboard', 1),
#   ('written', 1),
#   ('number', 1),
#   ('record', 1),
#   ('daughter', 1),
#   ('polish', 0),
#   ('police', 0),
#   ('abbey', 0),
#   ('poco', 0),
#   ('pollution', 0),
#   ('player', 0),
#   ('play', 0),
#   ('platinum', 0),
#   ('place', 0),
#   ('pipe', 0),
#   ('pink', 0),
#   ('piggy', 0),
#   ('pierrot', 0),
#   ('pleasure', 0),
#   ('popular', 0),
#   ('pope', 0),
#   ('preceding', 0)],
#  "(She's_So)_Selfish": [('inspired', 2),
#   ('single', 2),
#   ('knack', 2),
#   ('compilation', 1),
#   ('selfish', 1),
#   ('debut', 1),
#   ('release', 1),
#   ('album', 1),
#   ('scatological', 1),
#   ('hit', 1),
#   ('number', 1),
#   ('song', 1),
#   ('woman', 1),
#   ('live', 1),
#   ('nastiness', 1),
#   ('style', 1),
#   ('written', 1),
#   ('intended', 1),
#   ('pipe', 0),
#   ('piggy', 0),
#   ('pink', 0),
#   ('pollution', 0),
#   ('platinum', 0),
#   ('place', 0),
#   ('police', 0),
#   ('poco', 0),
#   ('pleasure', 0),
#   ('player', 0),
#   ('play', 0),
#   ('pop', 0)],
#  '(The_Same_Thing_Happens_with)_The_Birds_and_the_Bees': [('film', 4),
#   ('lady', 1),
#   ('bees', 1),
#   ('screwball', 1),
#   ('starring', 1),
#   ('remake', 1),
#   ('story', 1),
#   ('eve', 1),
#   ('designed', 1),
#   ('comedy', 1),
#   ('head', 1),
#   ('written', 1),
#   ('based', 1),
#   ('directed', 1),
#   ('pink', 0),
#   ('piggy', 0),
#   ('pipe', 0),
#   ('place', 0),
#   ('platinum', 0),
#   ('pop', 0),
#   ('play', 0),
#   ('prince', 0),
#   ('player', 0),
#   ('pleasure', 0),
#   ('poco', 0),
#   ('primarily', 0),
#   ('police', 0),
#   ('polish', 0),
#   ('pollution', 0),
#   ('present', 0)],
#  "(What's_So_Funny_'Bout)_Peace,_Love,_and_Understanding": [('song', 4),
#   ('schwarz', 2),
#   ('album', 2),
#   ('single', 2),
#   ('version', 2),
#   ('new', 1),
#   ('nick', 1),
#   ('peace', 1),
#   ('great', 1),
#   ('popularity', 1),
#   ('whats', 1),
#   ('cover', 1),
#   ('included', 1),
#   ('covered', 1),
#   ('love', 1),
#   ('initially', 1),
#   ('famously', 1),
#   ('squirm', 1),
#   ('understanding', 1),
#   ('written', 1),
#   ('did', 1),
#   ('bout', 1),
#   ('armed', 1),
#   ('saw', 1),
#   ('funny', 1),
#   ('band', 1),
#   ('later', 1),
#   ('solo', 1),
#   ('play', 0),
#   ('player', 0)],
#  '(What_Is)_Love%3F': [('abbey', 0),
#   ('process', 0),
#   ('pop', 0),
#   ('pollution', 0),
#   ('polish', 0),
#   ('police', 0),
#   ('poco', 0),
#   ('pleasure', 0),
#   ('player', 0),
#   ('play', 0),
#   ('platinum', 0),
#   ('place', 0),
#   ('pipe', 0),
#   ('pink', 0),
#   ('piggy', 0),
#   ('pierrot', 0),
#   ('pier', 0),
#   ('piece', 0),
#   ('piano', 0),
#   ('pope', 0),
#   ('popular', 0),
#   ('popularity', 0),
#   ('prelude', 0),
#   ('prior', 0),
#   ('prince', 0),
#   ('primarily', 0),
#   ('previously', 0),
#   ('previous', 0),
#   ('pretty', 0),
#   ('present', 0)],
#  '1+1_(song)': [('music', 4),
#   ('idol', 3),
#   ('ballad', 3),
#   ('love', 3),
#   ('video', 3),
#   ('hot', 2),
#   ('performance', 2),
#   ('positive', 2),
#   ('soul', 2),
#   ('chart', 2),
#   ('concert', 2),
#   ('studio', 2),
#   ('different', 2),
#   ('power', 2),
#   ('number', 2),
#   ('album', 2),
#   ('received', 2),
#   ('reception', 2),
#   ('clip', 2),
#   ('live', 2),
#   ('camera', 1),
#   ('innovative', 1),
#   ('initially', 1),
#   ('promotional', 1),
#   ('dance', 1),
#   ('peaked', 1),
#   ('united', 1),
#   ('heavy', 1),
#   ('considerable', 1),
#   ('instrumentation', 1)],
#  '100%25_(Mariah_Carey_song)': [('abbey', 0),
#   ('process', 0),
#   ('pop', 0),
#   ('pollution', 0),
#   ('polish', 0),
#   ('police', 0),
#   ('poco', 0),
#   ('pleasure', 0),
#   ('player', 0),
#   ('play', 0),
#   ('platinum', 0),
#   ('place', 0),
#   ('pipe', 0),
#   ('pink', 0),
#   ('piggy', 0),
#   ('pierrot', 0),
#   ('pier', 0),
#   ('piece', 0),
#   ('piano', 0),
#   ('pope', 0),
#   ('popular', 0),
#   ('popularity', 0),
#   ('prelude', 0),
#   ('prior', 0),
#   ('prince', 0),
#   ('primarily', 0),
#   ('previously', 0),
#   ('previous', 0),
#   ('pretty', 0),
#   ('present', 0)],
#  "100%25_d'amour": [('abbey', 0),
#   ('process', 0),
#   ('pop', 0),
#   ('pollution', 0),
#   ('polish', 0),
#   ('police', 0),
#   ('poco', 0),
#   ('pleasure', 0),
#   ('player', 0),
#   ('play', 0),
#   ('platinum', 0),
#   ('place', 0),
#   ('pipe', 0),
#   ('pink', 0),
#   ('piggy', 0),
#   ('pierrot', 0),
#   ('pier', 0),
#   ('piece', 0),
#   ('piano', 0),
#   ('pope', 0),
#   ('popular', 0),
#   ('popularity', 0),
#   ('prelude', 0),
#   ('prior', 0),
#   ('prince', 0),
#   ('primarily', 0),
#   ('previously', 0),
#   ('previous', 0),
#   ('pretty', 0),
#   ('present', 0)],
#  '100%25_te_ljubam': [('abbey', 0),
#   ('process', 0),
#   ('pop', 0),
#   ('pollution', 0),
#   ('polish', 0),
#   ('police', 0),
#   ('poco', 0),
#   ('pleasure', 0),
#   ('player', 0),
#   ('play', 0),
#   ('platinum', 0),
#   ('place', 0),
#   ('pipe', 0),
#   ('pink', 0),
#   ('piggy', 0),
#   ('pierrot', 0),
#   ('pier', 0),
#   ('piece', 0),
#   ('piano', 0),
#   ('pope', 0),
#   ('popular', 0),
#   ('popularity', 0),
#   ('prelude', 0),
#   ('prior', 0),
#   ('prince', 0),
#   ('primarily', 0),
#   ('previously', 0),
#   ('previous', 0),
#   ('pretty', 0),
#   ('present', 0)],
#  '100_Years_Ago': [('head', 1),
#   ('soup', 1),
#   ('featured', 1),
#   ('ago', 1),
#   ('song', 1),
#   ('rolling', 1),
#   ('album', 1),
#   ('rock', 1),
#   ('band', 1),
#   ('platinum', 0),
#   ('place', 0),
#   ('play', 0),
#   ('pop', 0),
#   ('player', 0),
#   ('pipe', 0),
#   ('pleasure', 0),
#   ('poco', 0),
#   ('pink', 0),
#   ('piggy', 0),
#   ('pierrot', 0),
#   ('police', 0),
#   ('polish', 0),
#   ('pollution', 0),
#   ('abbey', 0),
#   ('pier', 0),
#   ('popular', 0),
#   ('prince', 0),
#   ('primarily', 0),
#   ('previously', 0),
#   ('previous', 0)],
#  '10:15_Saturday_Night': [('track', 3),
#   ('song', 3),
#   ('album', 3),
#   ('cure', 2),
#   ('single', 2),
#   ('imaginary', 2),
#   ('live', 2),
#   ('band', 2),
#   ('massive', 1),
#   ('night', 1),
#   ('attention', 1),
#   ('attack', 1),
#   ('included', 1),
#   ('area', 1),
#   ('watching', 1),
#   ('video', 1),
#   ('man', 1),
#   ('tap', 1),
#   ('record', 1),
#   ('table', 1),
#   ('debut', 1),
#   ('smith', 1),
#   ('evening', 1),
#   ('newly', 1),
#   ('opening', 1),
#   ('utterly', 1),
#   ('mezzanine', 1),
#   ('company', 1),
#   ('booklet', 1),
#   ('fiction', 1)],
#  '11_(song)': [('song', 2),
#   ('pope', 2),
#   ('frame', 2),
#   ('chapman', 1),
#   ('debut', 1),
#   ('production', 1),
#   ('divorce', 1),
#   ('solo', 1),
#   ('handled', 1),
#   ('huff', 1),
#   ('story', 1),
#   ('album', 1),
#   ('polish', 0),
#   ('police', 0),
#   ('poco', 0),
#   ('abbey', 0),
#   ('pleasure', 0),
#   ('pollution', 0),
#   ('play', 0),
#   ('platinum', 0),
#   ('place', 0),
#   ('pipe', 0),
#   ('pink', 0),
#   ('piggy', 0),
#   ('pierrot', 0),
#   ('player', 0),
#   ('popular', 0),
#   ('pop', 0),
#   ('piece', 0),
#   ('previously', 0)],
#  '12-Bar_Original': [('song', 3),
#   ('instrumental', 3),
#   ('music', 2),
#   ('version', 2),
#   ('flying', 2),
#   ('tour', 2),
#   ('original', 2),
#   ('abbey', 1),
#   ('cover', 1),
#   ('shadow', 1),
#   ('single', 1),
#   ('commercially', 1),
#   ('startling', 1),
#   ('cayenne', 1),
#   ('book', 1),
#   ('time', 1),
#   ('recall', 1),
#   ('told', 1),
#   ('blues', 1),
#   ('track', 1),
#   ('black', 1),
#   ('unissued', 1),
#   ('bar', 1),
#   ('used', 1),
#   ('dig', 1),
#   ('quote', 1),
#   ('radio', 1),
#   ('anthology', 1),
#   ('later', 1),
#   ('length', 1)],
#  '13th_August_(instrumental)': [('progressive', 2),
#   ('successful', 1),
#   ('help', 1),
#   ('bring', 1),
#   ('early', 1),
#   ('briefly', 1),
#   ('guitarist', 1),
#   ('splash', 1),
#   ('title', 1),
#   ('sound', 1),
#   ('instrumental', 1),
#   ('player', 1),
#   ('keyboard', 1),
#   ('music', 1),
#   ('song', 1),
#   ('pleasure', 1),
#   ('short', 1),
#   ('express', 1),
#   ('compose', 1),
#   ('predominantly', 1),
#   ('band', 1),
#   ('drummer', 1),
#   ('bassist', 1),
#   ('rock', 1),
#   ('known', 1),
#   ('central', 1),
#   ('peace', 0),
#   ('pollution', 0),
#   ('positive', 0),
#   ('popularity', 0)],
#  '14_Years': [('illusion', 1),
#   ('rock', 1),
#   ('use', 1),
#   ('song', 1),
#   ('album', 1),
#   ('band', 1),
#   ('originally', 0),
#   ('organ', 0),
#   ('popular', 0),
#   ('pope', 0),
#   ('pop', 0),
#   ('pollution', 0),
#   ('polish', 0),
#   ('police', 0),
#   ('poco', 0),
#   ('pleasure', 0),
#   ('positive', 0),
#   ('player', 0),
#   ('play', 0),
#   ('platinum', 0),
#   ('place', 0),
#   ('pipe', 0),
#   ('pink', 0),
#   ('piggy', 0),
#   ('popularity', 0),
#   ('posse', 0),
#   ('outlook', 0),
#   ('pretty', 0),
#   ('prism', 0),
#   ('prior', 0)],
#  '157_Riverside_Avenue': [('live', 7),
#   ('song', 6),
#   ('version', 5),
#   ('length', 3),
#   ('album', 3),
#   ('band', 3),
#   ('included', 2),
#   ('lead', 2),
#   ('guitar', 2),
#   ('piano', 2),
#   ('stayed', 2),
#   ('make', 1),
#   ('way', 1),
#   ('time', 1),
#   ('guitarist', 1),
#   ('extended', 1),
#   ('arch', 1),
#   ('end', 1),
#   ('title', 1),
#   ('recording', 1),
#   ('bass', 1),
#   ('vocalist', 1),
#   ('decade', 1),
#   ('march', 1),
#   ('roll', 1),
#   ('introduction', 1),
#   ('solo', 1),
#   ('radio', 1),
#   ('neal', 1),
#   ('interlude', 1)],
#  '1762_leto': [('song', 6),
#   ('band', 2),
#   ('popular', 2),
#   ('science', 2),
#   ('include', 1),
#   ('place', 1),
#   ('ecumenical', 1),
#   ('st', 1),
#   ('alternative', 1),
#   ('folklore', 1),
#   ('nineteenth', 1),
#   ('folk', 1),
#   ('anniversary', 1),
#   ('magazine', 1),
#   ('archbishop', 1),
#   ('archbishopric', 1),
#   ('time', 1),
#   ('final', 1),
#   ('collection', 1),
#   ('periodical', 1),
#   ('national', 1),
#   ('mark', 1),
#   ('took', 1),
#   ('especially', 1),
#   ('victory', 1),
#   ('movement', 1),
#   ('shortly', 1),
#   ('previous', 1),
#   ('departure', 1),
#   ('wedding', 1)],
#  '17_(Avril_Lavigne_song)': [('album', 10),
#   ('music', 5),
#   ('reaching', 4),
#   ('number', 4),
#   ('fifth', 3),
#   ('industrial', 2),
#   ('release', 2),
#   ('single', 2),
#   ('epic', 2),
#   ('week', 2),
#   ('japan', 2),
#   ('rock', 2),
#   ('tour', 2),
#   ('selling', 2),
#   ('china', 2),
#   ('singer', 2),
#   ('musical', 1),
#   ('contain', 1),
#   ('praising', 1),
#   ('power', 1),
#   ('featured', 1),
#   ('let', 1),
#   ('billboard', 1),
#   ('controversial', 1),
#   ('country', 1),
#   ('moderately', 1),
#   ('impacted', 1),
#   ('production', 1),
#   ('promote', 1),
#   ('unnatural', 1)],
#  '18_(One_Direction_song)': [('album', 5),
#   ('band', 4),
#   ('united', 3),
#   ('music', 2),
#   ('number', 2),
#   ('direction', 2),
#   ('eleventh', 1),
#   ('tenth', 1),
#   ('positive', 1),
#   ('march', 1),
#   ('scoring', 1),
#   ('international', 1),
#   ('malik', 1),
#   ('debut', 1),
#   ('received', 1),
#   ('boy', 1),
#   ('federation', 1),
#   ('industry', 1),
#   ('sixth', 1),
#   ('sold', 1),
#   ('night', 1),
#   ('phonographic', 1),
#   ('status', 1),
#   ('member', 1),
#   ('steal', 1),
#   ('fourth', 1),
#   ('studio', 1),
#   ('leaving', 1),
#   ('generally', 1),
#   ('according', 1)],
#  '192_(song)': [('version', 2),
#   ('song', 2),
#   ('police', 1),
#   ('included', 1),
#   ('title', 1),
#   ('singer', 1),
#   ('read', 1),
#   ('second', 1),
#   ('telephone', 1),
#   ('north', 1),
#   ('album', 1),
#   ('number', 1),
#   ('poco', 0),
#   ('pleasure', 0),
#   ('player', 0),
#   ('abbey', 0),
#   ('polish', 0),
#   ('platinum', 0),
#   ('place', 0),
#   ('pipe', 0),
#   ('pink', 0),
#   ('piggy', 0),
#   ('pierrot', 0),
#   ('pier', 0),
#   ('play', 0),
#   ('popular', 0),
#   ('pollution', 0),
#   ('power', 0),
#   ('previous', 0),
#   ('pretty', 0)],
#  '1983..._(A_Merman_I_Should_Turn_to_Be)': [('song', 2),
#   ('band', 1),
#   ('duration', 1),
#   ('album', 1),
#   ('chile', 1),
#   ('group', 1),
#   ('traffic', 1),
#   ('wood', 1),
#   ('second', 1),
#   ('track', 1),
#   ('flute', 1),
#   ('player', 1),
#   ('turn', 1),
#   ('voodoo', 1),
#   ('merman', 1),
#   ('experience', 1),
#   ('written', 1),
#   ('produced', 1),
#   ('studio', 1),
#   ('electric', 1),
#   ('platinum', 0),
#   ('play', 0),
#   ('pleasure', 0),
#   ('place', 0),
#   ('pipe', 0),
#   ('pink', 0),
#   ('poco', 0),
#   ('police', 0),
#   ('popular', 0),
#   ('polish', 0)],
#  '1987_(song)': [('song', 6),
#   ('best', 3),
#   ('martin', 2),
#   ('video', 2),
#   ('category', 1),
#   ('musician', 1),
#   ('space', 1),
#   ('music', 1),
#   ('collective', 1),
#   ('astronaut', 1),
#   ('alternative', 1),
#   ('nominated', 1),
#   ('album', 1),
#   ('live', 1),
#   ('won', 1),
#   ('usually', 1),
#   ('award', 1),
#   ('directed', 1),
#   ('band', 1),
#   ('shown', 1),
#   ('led', 1),
#   ('studio', 1),
#   ('written', 1),
#   ('producer', 1),
#   ('produced', 1),
#   ('campo', 1),
#   ('pleasure', 0),
#   ('player', 0),
#   ('primarily', 0),
#   ('previously', 0)],
#  '1998_(instrumental)': [('music', 4),
#   ('armada', 3),
#   ('peaked', 2),
#   ('package', 2),
#   ('binary', 2),
#   ('delicious', 2),
#   ('track', 2),
#   ('anniversary', 2),
#   ('remix', 2),
#   ('title', 2),
#   ('year', 2),
#   ('morph', 1),
#   ('numerous', 1),
#   ('instrumental', 1),
#   ('trance', 1),
#   ('release', 1),
#   ('times', 1),
#   ('jordan', 1),
#   ('end', 1),
#   ('mark', 1),
#   ('baby', 1),
#   ('debut', 1),
#   ('covered', 1),
#   ('peace', 1),
#   ('version', 1),
#   ('sell', 1),
#   ('originally', 1),
#   ('song', 1),
#   ('kissy', 1),
#   ('produced', 1)],
#  '1_Life_(Xandee_song)': [('song', 3),
#   ('contest', 2),
#   ('close', 1),
#   ('representative', 1),
#   ('semifinal', 1),
#   ('received', 1),
#   ('following', 1),
#   ('stage', 1),
#   ('number', 1),
#   ('thirteenth', 1),
#   ('sandy', 1),
#   ('grand', 1),
#   ('advantage', 1),
#   ('entry', 1),
#   ('believe', 1),
#   ('solo', 1),
#   ('compete', 1),
#   ('final', 1),
#   ('place', 1),
#   ('did', 1),
#   ('voting', 1),
#   ('singing', 1),
#   ('single', 1),
#   ('opportunity', 1),
#   ('life', 1),
#   ('preceding', 1),
#   ('need', 1),
#   ('police', 0),
#   ('poco', 0),
#   ('platinum', 0)],
#  '1_Train_(song)': [('song', 4),
#   ('album', 2),
#   ('produced', 1),
#   ('high', 1),
#   ('release', 1),
#   ('bubbling', 1),
#   ('brown', 1),
#   ('joey', 1),
#   ('debut', 1),
#   ('recording', 1),
#   ('cut', 1),
#   ('artist', 1),
#   ('hip', 1),
#   ('long', 1),
#   ('fellow', 1),
#   ('track', 1),
#   ('train', 1),
#   ('feel', 1),
#   ('posse', 1),
#   ('billboard', 1),
#   ('big', 1),
#   ('hop', 1),
#   ('hot', 1),
#   ('singles', 1),
#   ('number', 1),
#   ('underground', 1),
#   ('chart', 1),
#   ('additional', 1),
#   ('peaking', 1),
#   ('rocky', 1)],
#  '2112_(song)': [('song', 6),
#   ('album', 2),
#   ('live', 2),
#   ('section', 1),
#   ('combined', 1),
#   ('syrinx', 1),
#   ('used', 1),
#   ('step', 1),
#   ('pronounced', 1),
#   ('starting', 1),
#   ('test', 1),
#   ('echo', 1),
#   ('long', 1),
#   ('comic', 1),
#   ('rush', 1),
#   ('featured', 1),
#   ('tour', 1),
#   ('cover', 1),
#   ('band', 1),
#   ('suite', 1),
#   ('library', 1),
#   ('different', 1),
#   ('overture', 1),
#   ('minute', 1),
#   ('rock', 1),
#   ('single', 1),
#   ('booklet', 1),
#   ('play', 0),
#   ('player', 0),
#   ('pleasure', 0)],
#  '2120_South_Michigan_Avenue': [('title', 3),
#   ('track', 3),
#   ('second', 3),
#   ('song', 3),
#   ('south', 3),
#   ('version', 3),
#   ('michigan', 3),
#   ('riff', 3),
#   ('credit', 3),
#   ('sound', 2),
#   ('composition', 2),
#   ('rolling', 2),
#   ('original', 2),
#   ('band', 2),
#   ('avenue', 2),
#   ('listed', 2),
#   ('chess', 2),
#   ('album', 2),
#   ('short', 1),
#   ('tremolo', 1),
#   ('cover', 1),
#   ('process', 1),
#   ('better', 1),
#   ('originally', 1),
#   ('minute', 1),
#   ('fading', 1),
#   ('bass', 1),
#   ('based', 1),
#   ('unreleased', 1),
#   ('instrumental', 1)],
#  '21st_Century_Schizoid_Man': [('crimson', 2),
#   ('king', 2),
#   ('progressive', 1),
#   ('rock', 1),
#   ('schizoid', 1),
#   ('century', 1),
#   ('album', 1),
#   ('song', 1),
#   ('debut', 1),
#   ('man', 1),
#   ('band', 1),
#   ('court', 1),
#   ('pleasure', 0),
#   ('poco', 0),
#   ('player', 0),
#   ('police', 0),
#   ('polish', 0),
#   ('play', 0),
#   ('platinum', 0),
#   ('place', 0),
#   ('pipe', 0),
#   ('pollution', 0),
#   ('pop', 0),
#   ('pope', 0),
#   ('popular', 0),
#   ('posse', 0),
#   ('popularity', 0),
#   ('positive', 0),
#   ('process', 0),
#   ('prism', 0)],
#  '23_Minutes_Over_Brussels': [('recording', 3),
#   ('debut', 1),
#   ('heyday', 1),
#   ('performance', 1),
#   ('release', 1),
#   ('duo', 1),
#   ('indication', 1),
#   ('june', 1),
#   ('clash', 1),
#   ('supporting', 1),
#   ('reaction', 1),
#   ('album', 1),
#   ('live', 1),
#   ('largely', 1),
#   ('suicide', 1),
#   ('unheard', 1),
#   ('reissue', 1),
#   ('pleasure', 0),
#   ('poco', 0),
#   ('play', 0),
#   ('player', 0),
#   ('platinum', 0),
#   ('place', 0),
#   ('pipe', 0),
#   ('pink', 0),
#   ('piggy', 0),
#   ('pierrot', 0),
#   ('pier', 0),
#   ('piece', 0),
#   ('police', 0)],
#  "24's_(RichGirl_song)": [('song', 4),
#   ('group', 2),
#   ('multiple', 2),
#   ('hot', 1),
#   ('rapper', 1),
#   ('times', 1),
#   ('child', 1),
#   ('album', 1),
#   ('debut', 1),
#   ('peak', 1),
#   ('number', 1),
#   ('pronounced', 1),
#   ('bun', 1),
#   ('promotional', 1),
#   ('rich', 1),
#   ('produced', 1),
#   ('girl', 1),
#   ('united', 1),
#   ('single', 1),
#   ('acclaim', 1),
#   ('critical', 1),
#   ('predominantly', 0),
#   ('poco', 0),
#   ('piggy', 0),
#   ('power', 0),
#   ('pretty', 0),
#   ('pink', 0),
#   ('pipe', 0),
#   ('place', 0),
#   ('platinum', 0)],
#  '24_Hrs._to_Live': [('radio', 2),
#   ('version', 2),
#   ('album', 2),
#   ('brown', 2),
#   ('pen', 2),
#   ('foxy', 2),
#   ('kim', 2),
#   ('song', 2),
#   ('queen', 2),
#   ('solely', 1),
#   ('female', 1),
#   ('lox', 1),
#   ('fell', 1),
#   ('cut', 1),
#   ('debut', 1),
#   ('interview', 1),
#   ('rapper', 1),
#   ('taken', 1),
#   ('live', 1),
#   ('urban', 1),
#   ('black', 1),
#   ('later', 1),
#   ('chart', 1),
#   ('resulting', 1),
#   ('project', 1),
#   ('frustration', 1),
#   ('cancellation', 1),
#   ('rob', 1),
#   ('year', 1),
#   ('life', 1)],
#  '25_Minutes_to_Go': [('album', 1),
#   ('inside', 1),
#   ('folk', 1),
#   ('song', 1),
#   ('play', 0),
#   ('polish', 0),
#   ('police', 0),
#   ('poco', 0),
#   ('pleasure', 0),
#   ('player', 0),
#   ('abbey', 0),
#   ('pianist', 0),
#   ('platinum', 0),
#   ('place', 0),
#   ('pipe', 0),
#   ('pink', 0),
#   ('piggy', 0),
#   ('pierrot', 0),
#   ('pier', 0),
#   ('piece', 0),
#   ('pollution', 0),
#   ('pop', 0),
#   ('pope', 0),
#   ('popular', 0),
#   ('prince', 0),
#   ('primarily', 0),
#   ('previously', 0),
#   ('previous', 0),
#   ('pretty', 0),
#   ('present', 0)],
#  '2HB': [('music', 3),
#   ('bogart', 3),
#   ('song', 3),
#   ('roxy', 3),
#   ('album', 2),
#   ('ferry', 2),
#   ('piano', 1),
#   ('featured', 1),
#   ('effects', 1),
#   ('melody', 1),
#   ('tape', 1),
#   ('dedication', 1),
#   ('time', 1),
#   ('version', 1),
#   ('debut', 1),
#   ('star', 1),
#   ('recording', 1),
#   ('solo', 1),
#   ('stick', 1),
#   ('prominently', 1),
#   ('particular', 1),
#   ('instrumentation', 1),
#   ('dominated', 1),
#   ('title', 1),
#   ('film', 1),
#   ('classic', 1),
#   ('written', 1),
#   ('sax', 1),
#   ('electric', 1),
#   ('goes', 1)],
#  '2_Long_(Andrzej_Piaseczny_song)': [('contest', 4),
#   ('polish', 4),
#   ('song', 4),
#   ('entry', 3),
#   ('following', 2),
#   ('did', 2),
#   ('wearing', 1),
#   ('country', 1),
#   ('brown', 1),
#   ('number', 1),
#   ('include', 1),
#   ('man', 1),
#   ('taking', 1),
#   ('wer', 1),
#   ('taken', 1),
#   ('decision', 1),
#   ('eighteenth', 1),
#   ('music', 1),
#   ('energy', 1),
#   ('close', 1),
#   ('lover', 1),
#   ('female', 1),
#   ('urban', 1),
#   ('voting', 1),
#   ('coat', 1),
#   ('backing', 1),
#   ('night', 1),
#   ('field', 1),
#   ('blue', 1),
#   ('time', 1)],
#  '2_Rights_Make_1_Wrong': [('album', 2),
#   ('band', 1),
#   ('produced', 1),
#   ('york', 1),
#   ('rev', 1),
#   ('action', 1),
#   ('rock', 1),
#   ('new', 1),
#   ('studio', 1),
#   ('player', 0),
#   ('pop', 0),
#   ('pollution', 0),
#   ('polish', 0),
#   ('police', 0),
#   ('poco', 0),
#   ('pleasure', 0),
#   ('platinum', 0),
#   ('play', 0),
#   ('popular', 0),
#   ('place', 0),
#   ('pipe', 0),
#   ('pink', 0),
#   ('piggy', 0),
#   ('pierrot', 0),
#   ('pier', 0),
#   ('pope', 0),
#   ('posse', 0),
#   ('popularity', 0),
#   ('prelude', 0),
#   ('prior', 0)],
#  '3-Minute_Rule': [('track', 2),
#   ('beastie', 2),
#   ('written', 1),
#   ('group', 1),
#   ('hip', 1),
#   ('album', 1),
#   ('hop', 1),
#   ('dust', 1),
#   ('rule', 1),
#   ('produced', 1),
#   ('place', 0),
#   ('pipe', 0),
#   ('platinum', 0),
#   ('pollution', 0),
#   ('pink', 0),
#   ('play', 0),
#   ('player', 0),
#   ('piggy', 0),
#   ('pierrot', 0),
#   ('pleasure', 0),
#   ('poco', 0),
#   ('police', 0),
#   ('polish', 0),
#   ('pier', 0),
#   ('abbey', 0),
#   ('pope', 0),
#   ('pop', 0),
#   ('praising', 0),
#   ('previously', 0),
#   ('previous', 0)],
#  '3.6.5': [('album', 5),
#   ('singles', 3),
#   ('chart', 2),
#   ('debut', 2),
#   ('growl', 2),
#   ('music', 2),
#   ('million', 1),
#   ('june', 1),
#   ('edition', 1),
#   ('went', 1),
#   ('entering', 1),
#   ('entertainment', 1),
#   ('august', 1),
#   ('version', 1),
#   ('band', 1),
#   ('lead', 1),
#   ('hug', 1),
#   ('wolf', 1),
#   ('hot', 1),
#   ('billboard', 1),
#   ('sold', 1),
#   ('south', 1),
#   ('boy', 1),
#   ('number', 1),
#   ('peaked', 1),
#   ('single', 1),
#   ('studio', 1),
#   ('year', 1),
#   ('won', 1),
#   ('distributed', 1)],
#  '300_M.P.H._Torrential_Outpour_Blues': [('blues', 6),
#   ('song', 6),
#   ('white', 4),
#   ('unexpected', 1),
#   ('post', 1),
#   ('shuffle', 1),
#   ('fading', 1),
#   ('country', 1),
#   ('use', 1),
#   ('screeching', 1),
#   ('violently', 1),
#   ('mark', 1),
#   ('quiet', 1),
#   ('warning', 1),
#   ('jack', 1),
#   ('real', 1),
#   ('really', 1),
#   ('moment', 1),
#   ('torrential', 1),
#   ('track', 1),
#   ('thump', 1),
#   ('heavy', 1),
#   ('nearly', 1),
#   ('break', 1),
#   ('sound', 1),
#   ('half', 1),
#   ('guitarist', 1),
#   ('guitar', 1),
#   ('switch', 1),
#   ('past', 1)],
#  '32_Flavors': [('song', 6),
#   ('featured', 2),
#   ('number', 2),
#   ('ad', 2),
#   ('football', 1),
#   ('romantic', 1),
#   ('national', 1),
#   ('variation', 1),
#   ('album', 1),
#   ('slogan', 1),
#   ('covered', 1),
#   ('debut', 1),
#   ('better', 1),
#   ('cream', 1),
#   ('ani', 1),
#   ('movie', 1),
#   ('comedy', 1),
#   ('pretty', 1),
#   ('play', 1),
#   ('title', 1),
#   ('used', 1),
#   ('later', 1),
#   ('girl', 1),
#   ('ice', 1),
#   ('sixth', 1),
#   ('campaign', 1),
#   ('store', 1),
#   ('league', 1),
#   ('studio', 1),
#   ('worn', 1)],
#  '34_(song)': [('song', 4),
#   ('band', 2),
#   ('track', 2),
#   ('album', 2),
#   ('table', 1),
#   ('number', 1),
#   ('pay', 1),
#   ('percussionist', 1),
#   ('piece', 1),
#   ('hepatitis', 1),
#   ('debut', 1),
#   ('collaborator', 1),
#   ('hidden', 1),
#   ('studio', 1),
#   ('suicide', 1),
#   ('featured', 1),
#   ('previous', 1),
#   ('inspired', 1),
#   ('instrumental', 1),
#   ('blank', 1),
#   ('later', 1),
#   ('carter', 1),
#   ('written', 1),
#   ('pipe', 0),
#   ('response', 0),
#   ('restrict', 0),
#   ('platinum', 0),
#   ('result', 0),
#   ('resulting', 0),
#   ('place', 0)],
#  '40,000_Headmen': [('song', 7),
#   ('album', 5),
#   ('traffic', 3),
#   ('blood', 3),
#   ('sweat', 3),
#   ('music', 2),
#   ('tour', 2),
#   ('box', 2),
#   ('protagonist', 2),
#   ('version', 2),
#   ('mason', 2),
#   ('dream', 2),
#   ('dreamlike', 1),
#   ('fact', 1),
#   ('single', 1),
#   ('demigod', 1),
#   ('set', 1),
#   ('title', 1),
#   ('profane', 1),
#   ('faith', 1),
#   ('taking', 1),
#   ('eponymous', 1),
#   ('number', 1),
#   ('foot', 1),
#   ('involvement', 1),
#   ('dear', 1),
#   ('written', 1),
#   ('face', 1),
#   ('despite', 1),
#   ('folk', 1)],
#  '41_(song)': [('album', 1),
#   ('band', 1),
#   ('song', 1),
#   ('featured', 1),
#   ('crash', 1),
#   ('pleasure', 0),
#   ('pop', 0),
#   ('pollution', 0),
#   ('polish', 0),
#   ('police', 0),
#   ('poco', 0),
#   ('abbey', 0),
#   ('popular', 0),
#   ('player', 0),
#   ('play', 0),
#   ('platinum', 0),
#   ('place', 0),
#   ('pipe', 0),
#   ('pink', 0),
#   ('piggy', 0),
#   ('pope', 0),
#   ('popularity', 0),
#   ('pier', 0),
#   ('prelude', 0),
#   ('prior', 0),
#   ('prince', 0),
#   ('primarily', 0),
#   ('previously', 0),
#   ('previous', 0),
#   ('pretty', 0)],
#  '42_(song)': [('song', 3),
#   ('band', 2),
#   ('album', 2),
#   ('live', 2),
#   ('rock', 2),
#   ('fourth', 1),
#   ('ballad', 1),
#   ('version', 1),
#   ('featured', 1),
#   ('viva', 1),
#   ('solo', 1),
#   ('arrangement', 1),
#   ('finally', 1),
#   ('chorus', 1),
#   ('death', 1),
#   ('guitar', 1),
#   ('piano', 1),
#   ('written', 1),
#   ('la', 1),
#   ('divided', 1),
#   ('does', 1),
#   ('passive', 0),
#   ('pop', 0),
#   ('overture', 0),
#   ('popularity', 0),
#   ('popular', 0),
#   ('pope', 0),
#   ('polish', 0),
#   ('pollution', 0),
#   ('posse', 0)],
#  '4_Carats': [('number', 3),
#   ('song', 3),
#   ('album', 3),
#   ('holiday', 3),
#   ('wrapped', 3),
#   ('artist', 2),
#   ('chart', 2),
#   ('ending', 2),
#   ('digital', 2),
#   ('release', 2),
#   ('pop', 2),
#   ('week', 2),
#   ('written', 2),
#   ('red', 2),
#   ('studio', 2),
#   ('ambivalent', 1),
#   ('lyrically', 1),
#   ('production', 1),
#   ('received', 1),
#   ('day', 1),
#   ('following', 1),
#   ('took', 1),
#   ('baby', 1),
#   ('south', 1),
#   ('voluptuous', 1),
#   ('sound', 1),
#   ('helmed', 1),
#   ('international', 1),
#   ('cut', 1),
#   ('materialism', 1)],
#  '4_the_Tears_in_Your_Eyes': [('album', 5),
#   ('live', 3),
#   ('rock', 2),
#   ('track', 2),
#   ('song', 2),
#   ('world', 2),
#   ('title', 2),
#   ('famine', 2),
#   ('included', 2),
#   ('relief', 2),
#   ('band', 2),
#   ('turner', 1),
#   ('trapped', 1),
#   ('bass', 1),
#   ('tour', 1),
#   ('topped', 1),
#   ('unreleased', 1),
#   ('born', 1),
#   ('box', 1),
#   ('version', 1),
#   ('northern', 1),
#   ('obscure', 1),
#   ('good', 1),
#   ('street', 1),
#   ('chart', 1),
#   ('charity', 1),
#   ('previously', 1),
#   ('rendition', 1),
#   ('did', 1),
#   ('recording', 1)],
#  '4st_7lb': [('band', 1),
#   ('rock', 1),
#   ('alternative', 1),
#   ('song', 1),
#   ('album', 1),
#   ('manic', 1),
#   ('street', 1),
#   ('holy', 1),
#   ('welsh', 1),
#   ('pollution', 0),
#   ('polish', 0),
#   ('police', 0),
#   ('poco', 0),
#   ('prince', 0),
#   ('prior', 0),
#   ('pleasure', 0),
#   ('player', 0),
#   ('play', 0),
#   ('platinum', 0),
#   ('prism', 0),
#   ('place', 0),
#   ('pipe', 0),
#   ('pink', 0),
#   ('piggy', 0),
#   ('pierrot', 0),
#   ('primarily', 0),
#   ('pretty', 0),
#   ('present', 0),
#   ('pope', 0),
#   ('prelude', 0)],
#  '4th_Time_Around': [('blonde', 2),
#   ('song', 1),
#   ('bob', 1),
#   ('time', 1),
#   ('album', 1),
#   ('place', 0),
#   ('police', 0),
#   ('poco', 0),
#   ('pleasure', 0),
#   ('player', 0),
#   ('play', 0),
#   ('platinum', 0),
#   ('pipe', 0),
#   ('pollution', 0),
#   ('pink', 0),
#   ('piggy', 0),
#   ('pierrot', 0),
#   ('pier', 0),
#   ('piece', 0),
#   ('piano', 0),
#   ('polish', 0),
#   ('abbey', 0),
#   ('pianist', 0),
#   ('preceding', 0),
#   ('prince', 0),
#   ('primarily', 0),
#   ('previously', 0),
#   ('previous', 0),
#   ('pretty', 0),
#   ('present', 0)],
#  '4th_of_July_(U2_song)': [('band', 2),
#   ('track', 2),
#   ('song', 2),
#   ('live', 1),
#   ('bassist', 1),
#   ('concert', 1),
#   ('unbeknownst', 1),
#   ('sixth', 1),
#   ('instrumental', 1),
#   ('play', 1),
#   ('edge', 1),
#   ('ambient', 1),
#   ('san', 1),
#   ('guitarist', 1),
#   ('album', 1),
#   ('spontaneously', 1),
#   ('unforgettable', 1),
#   ('did', 1),
#   ('rock', 1),
#   ('pollution', 0),
#   ('positive', 0),
#   ('popularity', 0),
#   ('popular', 0),
#   ('pope', 0),
#   ('pop', 0),
#   ('polish', 0),
#   ('post', 0),
#   ('police', 0),
#   ('overture', 0),
#   ('poco', 0)],
#  '4x4_(song)': [('cyrus', 12),
#   ('album', 8),
#   ('video', 6),
#   ('music', 6),
#   ('record', 4),
#   ('single', 4),
#   ('career', 3),
#   ('pop', 3),
#   ('fourth', 2),
#   ('musical', 2),
#   ('billboard', 2),
#   ('montana', 2),
#   ('later', 2),
#   ('million', 2),
#   ('continued', 2),
#   ('studio', 2),
#   ('guest', 2),
#   ('tour', 2),
#   ('certified', 2),
#   ('singer', 2),
#   ('opening', 1),
#   ('rami', 1),
#   ('united', 1),
#   ('provocative', 1),
#   ('public', 1),
#   ('beaten', 1),
#   ('vocal', 1),
#   ('ball', 1),
#   ('platinum', 1),
#   ('august', 1)],
#  '5-10-15_Hours': [('brown', 2),
#   ('induction', 1),
#   ('hall', 1),
#   ('best', 1),
#   ('ruth', 1),
#   ('roll', 1),
#   ('work', 1),
#   ('fame', 1),
#   ('said', 1),
#   ('rock', 1),
#   ('song', 1),
#   ('sides', 1),
#   ('written', 1),
#   ('wrote', 1),
#   ('place', 0),
#   ('piggy', 0),
#   ('police', 0),
#   ('poco', 0),
#   ('pier', 0),
#   ('pierrot', 0),
#   ('pink', 0),
#   ('pleasure', 0),
#   ('platinum', 0),
#   ('pipe', 0),
#   ('player', 0),
#   ('pollution', 0),
#   ('play', 0),
#   ('polish', 0),
#   ('abbey', 0),
#   ('pop', 0)],
#  '5/4_(Gorillaz_song)': [('band', 2),
#   ('song', 2),
#   ('track', 2),
#   ('tour', 2),
#   ('rise', 1),
#   ('taking', 1),
#   ('clint', 1),
#   ('celebrity', 1),
#   ('subsequently', 1),
#   ('switch', 1),
#   ('time', 1),
#   ('brought', 1),
#   ('signature', 1),
#   ('title', 1),
#   ('biography', 1),
#   ('beth', 1),
#   ('single', 1),
#   ('second', 1),
#   ('virtual', 1),
#   ('guitar', 1),
#   ('live', 1),
#   ('intended', 1),
#   ('instead', 1),
#   ('included', 1),
#   ('minute', 1),
#   ('music', 1),
#   ('ogre', 1),
#   ('debut', 1),
#   ('originally', 1),
#   ('follow', 1)],
#  '53rd_&_3rd': [('rock', 1),
#   ('punk', 1),
#   ('band', 1),
#   ('song', 1),
#   ('play', 0),
#   ('pollution', 0),
#   ('polish', 0),
#   ('police', 0),
#   ('poco', 0),
#   ('pleasure', 0),
#   ('player', 0),
#   ('abbey', 0),
#   ('pope', 0),
#   ('platinum', 0),
#   ('place', 0),
#   ('pipe', 0),
#   ('pink', 0),
#   ('piggy', 0),
#   ('pierrot', 0),
#   ('pier', 0),
#   ('pop', 0),
#   ('popularity', 0),
#   ('popular', 0),
#   ('predominantly', 0),
#   ('prince', 0),
#   ('primarily', 0),
#   ('previously', 0),
#   ('previous', 0),
#   ('pretty', 0),
#   ('present', 0)],
#  '5:15_(Bridgit_Mendler_song)': [('song', 4),
#   ('chart', 2),
#   ('mad', 1),
#   ('music', 1),
#   ('number', 1),
#   ('debut', 1),
#   ('influence', 1),
#   ('album', 1),
#   ('recording', 1),
#   ('received', 1),
#   ('artist', 1),
#   ('country', 1),
#   ('instrumental', 1),
#   ('hello', 1),
#   ('soul', 1),
#   ('fifth', 1),
#   ('international', 1),
#   ('south', 1),
#   ('positive', 1),
#   ('making', 1),
#   ('produced', 1),
#   ('studio', 1),
#   ('composed', 1),
#   ('praising', 1),
#   ('singles', 1),
#   ('posse', 0),
#   ('player', 0),
#   ('previously', 0),
#   ('previous', 0),
#   ('platinum', 0)],
#  "7_O'Clock_News/Silent_Night": [('oclock', 2),
#   ('night', 2),
#   ('summer', 1),
#   ('track', 1),
#   ('duo', 1),
#   ('sage', 1),
#   ('album', 1),
#   ('silent', 1),
#   ('collage', 1),
#   ('song', 1),
#   ('music', 1),
#   ('sound', 1),
#   ('rendition', 1),
#   ('thyme', 1),
#   ('news', 1),
#   ('bulletin', 1),
#   ('parsley', 1),
#   ('studio', 1),
#   ('rosemary', 1),
#   ('carol', 1),
#   ('actual', 1),
#   ('replacement', 0),
#   ('pink', 0),
#   ('response', 0),
#   ('platinum', 0),
#   ('restrict', 0),
#   ('result', 0),
#   ('place', 0),
#   ('pipe', 0),
#   ('piggy', 0)],
#  '7_Skies_H3': [('composition', 1),
#   ('experimental', 1),
#   ('skies', 1),
#   ('rock', 1),
#   ('flaming', 1),
#   ('band', 1),
#   ('piggy', 0),
#   ('pleasure', 0),
#   ('pope', 0),
#   ('pop', 0),
#   ('pollution', 0),
#   ('polish', 0),
#   ('police', 0),
#   ('poco', 0),
#   ('player', 0),
#   ('pink', 0),
#   ('play', 0),
#   ('pierrot', 0),
#   ('popularity', 0),
#   ('platinum', 0),
#   ('place', 0),
#   ('pipe', 0),
#   ('popular', 0),
#   ('posse', 0),
#   ('positive', 0),
#   ('piece', 0),
#   ('prior', 0),
#   ('prince', 0),
#   ('primarily', 0),
#   ('previously', 0)],
#  '7th_Wonder': [('song', 4),
#   ('contest', 3),
#   ('seventh', 2),
#   ('singing', 2),
#   ('time', 2),
#   ('wonder', 2),
#   ('close', 1),
#   ('following', 1),
#   ('happy', 1),
#   ('man', 1),
#   ('scored', 1),
#   ('entry', 1),
#   ('waiting', 1),
#   ('marcel', 1),
#   ('equal', 1),
#   ('place', 1),
#   ('night', 1),
#   ('spell', 1),
#   ('real', 1),
#   ('score', 1),
#   ('tell', 1),
#   ('finish', 1),
#   ('audience', 1),
#   ('join', 1),
#   ('best', 1),
#   ('preceding', 1),
#   ('twentieth', 1),
#   ('composed', 1),
#   ('home', 1),
#   ('seven', 1)],
#  '9AM_in_Dallas': [('album', 4),
#   ('track', 3),
#   ('rapper', 2),
#   ('song', 2),
#   ('june', 2),
#   ('version', 2),
#   ('release', 2),
#   ('debut', 1),
#   ('number', 1),
#   ('included', 1),
#   ('billboard', 1),
#   ('later', 1),
#   ('eventual', 1),
#   ('days', 1),
#   ('thank', 1),
#   ('bonus', 1),
#   ('list', 1),
#   ('making', 1),
#   ('promotional', 1),
#   ('leading', 1),
#   ('present', 1),
#   ('strong', 1),
#   ('hot', 1),
#   ('store', 1),
#   ('drake', 1),
#   ('pink', 0),
#   ('pipe', 0),
#   ('place', 0),
#   ('prelude', 0),
#   ('play', 0)],
#  'A-Ba-Ni-Bi': [('song', 2),
#   ('language', 1),
#   ('game', 1),
#   ('winning', 1),
#   ('word', 1),
#   ('meaning', 1),
#   ('script', 1),
#   ('contest', 1),
#   ('abbey', 0),
#   ('pollution', 0),
#   ('polish', 0),
#   ('police', 0),
#   ('poco', 0),
#   ('pleasure', 0),
#   ('player', 0),
#   ('pope', 0),
#   ('play', 0),
#   ('platinum', 0),
#   ('place', 0),
#   ('pipe', 0),
#   ('pink', 0),
#   ('piggy', 0),
#   ('pierrot', 0),
#   ('pop', 0),
#   ('positive', 0),
#   ('popular', 0),
#   ('predominantly', 0),
#   ('prince', 0),
#   ('primarily', 0),
#   ('previously', 0)],
#  'A.D.H.D_(Kendrick_Lamar_song)': [('song', 2),
#   ('producer', 1),
#   ('studio', 1),
#   ('collaborator', 1),
#   ('rapper', 1),
#   ('album', 1),
#   ('debut', 1),
#   ('produced', 1),
#   ('frequent', 1),
#   ('overture', 0),
#   ('poco', 0),
#   ('pope', 0),
#   ('pop', 0),
#   ('pollution', 0),
#   ('originality', 0),
#   ('polish', 0),
#   ('police', 0),
#   ('originally', 0),
#   ('pleasure', 0),
#   ('popularity', 0),
#   ('player', 0),
#   ('play', 0),
#   ('outlook', 0),
#   ('platinum', 0),
#   ('place', 0),
#   ('pipe', 0),
#   ('popular', 0),
#   ('positive', 0),
#   ('piggy', 0),
#   ('posse', 0)],
#  'AOV_(song)': [('single', 3),
#   ('song', 2),
#   ('album', 2),
#   ('major', 1),
#   ('violence', 1),
#   ('promotional', 1),
#   ('metal', 1),
#   ('sixth', 1),
#   ('slipknot', 1),
#   ('band', 1),
#   ('heavy', 1),
#   ('fifth', 1),
#   ('chapter', 1),
#   ('gray', 1),
#   ('fourth', 1),
#   ('studio', 1),
#   ('overall', 1),
#   ('approaching', 1),
#   ('original', 1),
#   ('abbreviation', 1),
#   ('label', 1),
#   ('report', 0),
#   ('pipe', 0),
#   ('pleasure', 0),
#   ('player', 0),
#   ('resurgence', 0),
#   ('play', 0),
#   ('platinum', 0),
#   ('place', 0),
#   ('pink', 0)],
#  'A_Beginning': [('beginning', 2),
#   ('song', 2),
#   ('martin', 2),
#   ('real', 1),
#   ('night', 1),
#   ('anthology', 1),
#   ('piece', 1),
#   ('new', 1),
#   ('introduction', 1),
#   ('cue', 1),
#   ('film', 1),
#   ('scored', 1),
#   ('intended', 1),
#   ('instrumental', 1),
#   ('album', 1),
#   ('instead', 1),
#   ('solo', 1),
#   ('bird', 1),
#   ('used', 1),
#   ('included', 1),
#   ('incidental', 1),
#   ('composed', 1),
#   ('composition', 1),
#   ('producer', 1),
#   ('white', 1),
#   ('right', 1),
#   ('double', 1),
#   ('known', 1),
#   ('good', 1),
#   ('yellow', 1)],
#  'A_Blossom_Fell': [('king', 3),
#   ('cole', 3),
#   ('billboard', 2),
#   ('blossom', 2),
#   ('nat', 2),
#   ('song', 2),
#   ('fell', 2),
#   ('sides', 1),
#   ('note', 1),
#   ('chart', 1),
#   ('version', 1),
#   ('combined', 1),
#   ('era', 1),
#   ('combination', 1),
#   ('album', 1),
#   ('peaking', 1),
#   ('recording', 1),
#   ('record', 1),
#   ('data', 1),
#   ('magazine', 1),
#   ('number', 1),
#   ('status', 1),
#   ('written', 1),
#   ('popular', 1),
#   ('story', 1),
#   ('polish', 0),
#   ('previously', 0),
#   ('previous', 0),
#   ('platinum', 0),
#   ('play', 0)],
#  'A_Case_of_You': [('album', 1),
#   ('case', 1),
#   ('blue', 1),
#   ('song', 1),
#   ('pollution', 0),
#   ('polish', 0),
#   ('police', 0),
#   ('poco', 0),
#   ('pleasure', 0),
#   ('player', 0),
#   ('play', 0),
#   ('abbey', 0),
#   ('pope', 0),
#   ('platinum', 0),
#   ('place', 0),
#   ('pipe', 0),
#   ('pink', 0),
#   ('piggy', 0),
#   ('pierrot', 0),
#   ('pier', 0),
#   ('pop', 0),
#   ('popular', 0),
#   ('piano', 0),
#   ('popularity', 0),
#   ('prior', 0),
#   ('prince', 0),
#   ('primarily', 0),
#   ('previously', 0),
#   ('previous', 0),
#   ('pretty', 0)],
#  'A_Century_of_Love': [('song', 3),
#   ('final', 2),
#   ('contest', 2),
#   ('geta', 1),
#   ('century', 1),
#   ('time', 1),
#   ('love', 1),
#   ('received', 1),
#   ('san', 1),
#   ('night', 1),
#   ('entry', 1),
#   ('history', 1),
#   ('following', 1),
#   ('semifinal', 1),
#   ('make', 1),
#   ('complice', 1),
#   ('preceding', 1),
#   ('sung', 1),
#   ('composed', 1),
#   ('failing', 1),
#   ('absent', 1),
#   ('place', 0),
#   ('platinum', 0),
#   ('play', 0),
#   ('pleasure', 0),
#   ('previous', 0),
#   ('poco', 0),
#   ('pretty', 0),
#   ('previously', 0),
#   ('pipe', 0)],
#  'A_Cottage_for_Sale': [('song', 3),
#   ('cottage', 2),
#   ('sale', 2),
#   ('composed', 1),
#   ('new', 1),
#   ('popular', 1),
#   ('music', 1),
#   ('march', 1),
#   ('orchestra', 1),
#   ('larry', 1),
#   ('yorker', 1),
#   ('written', 1),
#   ('pope', 0),
#   ('pop', 0),
#   ('pollution', 0),
#   ('polish', 0),
#   ('police', 0),
#   ('abbey', 0),
#   ('poco', 0),
#   ('pleasure', 0),
#   ('play', 0),
#   ('platinum', 0),
#   ('place', 0),
#   ('pipe', 0),
#   ('pink', 0),
#   ('player', 0),
#   ('positive', 0),
#   ('popularity', 0),
#   ('prelude', 0),
#   ('prior', 0)],
#  'A_Criminal_Mind': [('gowan', 2),
#   ('animal', 1),
#   ('strange', 1),
#   ('mind', 1),
#   ('single', 1),
#   ('second', 1),
#   ('artist', 1),
#   ('song', 1),
#   ('criminal', 1),
#   ('album', 1),
#   ('number', 1),
#   ('signature', 1),
#   ('canada', 1),
#   ('studio', 1),
#   ('lead', 1),
#   ('overall', 0),
#   ('popular', 0),
#   ('pope', 0),
#   ('pop', 0),
#   ('pollution', 0),
#   ('polish', 0),
#   ('police', 0),
#   ('parsley', 0),
#   ('positive', 0),
#   ('poco', 0),
#   ('pleasure', 0),
#   ('player', 0),
#   ('play', 0),
#   ('platinum', 0),
#   ('overture', 0)],
#  'A_Day_in_the_Life': [('song', 5),
#   ('mainly', 2),
#   ('chord', 2),
#   ('inspired', 2),
#   ('band', 2),
#   ('middle', 2),
#   ('day', 1),
#   ('death', 1),
#   ('second', 1),
#   ('deep', 1),
#   ('smoking', 1),
#   ('segment', 1),
#   ('crescendo', 1),
#   ('creation', 1),
#   ('covered', 1),
#   ('riding', 1),
#   ('contemporary', 1),
#   ('company', 1),
#   ('class', 1),
#   ('club', 1),
#   ('reputed', 1),
#   ('style', 1),
#   ('sustained', 1),
#   ('bus', 1),
#   ('tara', 1),
#   ('broadcast', 1),
#   ('track', 1),
#   ('turn', 1),
#   ('beck', 1),
#   ('barry', 1)],
#  'A_Day_in_the_Life_of_a_Tree': [('band', 1),
#   ('song', 1),
#   ('environmental', 1),
#   ('pollution', 1),
#   ('album', 1),
#   ('tree', 1),
#   ('life', 1),
#   ('vocal', 1),
#   ('day', 1),
#   ('manager', 1),
#   ('rock', 1),
#   ('inspired', 1),
#   ('written', 1),
#   ('jack', 1),
#   ('lead', 1),
#   ('beach', 1),
#   ('pleasure', 0),
#   ('pope', 0),
#   ('player', 0),
#   ('play', 0),
#   ('platinum', 0),
#   ('poco', 0),
#   ('police', 0),
#   ('place', 0),
#   ('polish', 0),
#   ('pipe', 0),
#   ('pop', 0),
#   ('positive', 0),
#   ('popular', 0),
#   ('popularity', 0)],
#  'A_Fellow_Needs_a_Girl': [('broadway', 4),
#   ('musical', 3),
#   ('work', 3),
#   ('allegro', 2),
#   ('sought', 2),
#   ('cast', 2),
#   ('large', 2),
#   ('play', 2),
#   ('stage', 2),
#   ('production', 2),
#   ('end', 2),
#   ('tour', 1),
#   ('run', 1),
#   ('music', 1),
#   ('new', 1),
#   ('recording', 1),
#   ('west', 1),
#   ('immense', 1),
#   ('sale', 1),
#   ('moralistic', 1),
#   ('deal', 1),
#   ('ended', 1),
#   ('fortune', 1),
#   ('previous', 1),
#   ('mille', 1),
#   ('national', 1),
#   ('collaboration', 1),
#   ('rarely', 1),
#   ('props', 1),
#   ('haven', 1)],
#  'A_Great_Day_for_Freedom': [('bell', 1),
#   ('album', 1),
#   ('great', 1),
#   ('pink', 1),
#   ('division', 1),
#   ('day', 1),
#   ('freedom', 1),
#   ('song', 1),
#   ('pope', 0),
#   ('pop', 0),
#   ('pollution', 0),
#   ('polish', 0),
#   ('police', 0),
#   ('abbey', 0),
#   ('poco', 0),
#   ('popular', 0),
#   ('player', 0),
#   ('play', 0),
#   ('platinum', 0),
#   ('place', 0),
#   ('pipe', 0),
#   ('piggy', 0),
#   ('pierrot', 0),
#   ('pleasure', 0),
#   ('popularity', 0),
#   ('piece', 0),
#   ('prelude', 0),
#   ('prior', 0),
#   ('prince', 0),
#   ('primarily', 0)],
#  'A_Guy_Is_a_Guy': [('song', 10),
#   ('knave', 4),
#   ('version', 3),
#   ('chart', 3),
#   ('guy', 2),
#   ('based', 2),
#   ('march', 2),
#   ('brand', 2),
#   ('bridal', 1),
#   ('dating', 1),
#   ('chorus', 1),
#   ('number', 1),
#   ('widely', 1),
#   ('june', 1),
#   ('pipe', 1),
#   ('juke', 1),
#   ('proof', 1),
#   ('slob', 1),
#   ('popular', 1),
#   ('went', 1),
#   ('peaking', 1),
#   ('established', 1),
#   ('sang', 1),
#   ('days', 1),
#   ('war', 1),
#   ('day', 1),
#   ('flip', 1),
#   ('wedding', 1),
#   ('alehouse', 1),
#   ('actually', 1)],
#  'A_Guy_Like_You': [('song', 2),
#   ('stage', 2),
#   ('german', 1),
#   ('like', 1),
#   ('hunchback', 1),
#   ('production', 1),
#   ('console', 1),
#   ('try', 1),
#   ('version', 1),
#   ('featured', 1),
#   ('musical', 1),
#   ('dame', 1),
#   ('guy', 1),
#   ('flight', 1),
#   ('north', 1),
#   ('film', 1),
#   ('past', 0),
#   ('police', 0),
#   ('popularity', 0),
#   ('popular', 0),
#   ('pope', 0),
#   ('pop', 0),
#   ('pollution', 0),
#   ('polish', 0),
#   ('poco', 0),
#   ('posse', 0),
#   ('owing', 0),
#   ('pleasure', 0),
#   ('player', 0),
#   ('play', 0)],
#  "A_Hard_Rain's_a-Gonna_Fall": [('song', 4),
#   ('evil', 2),
#   ('feeling', 2),
#   ('bob', 2),
#   ('symbolist', 1),
#   ('saying', 1),
#   ('inspiration', 1),
#   ('culture', 1),
#   ('new', 1),
#   ('common', 1),
#   ('schism', 1),
#   ('public', 1),
#   ('days', 1),
#   ('taken', 1),
#   ('question', 1),
#   ('communicating', 1),
#   ('volume', 1),
#   ('warfare', 1),
#   ('said', 1),
#   ('answer', 1),
#   ('aware', 1),
#   ('missile', 1),
#   ('lyrical', 1),
#   ('memoir', 1),
#   ('traditional', 1),
#   ('human', 1),
#   ('black', 1),
#   ('fall', 1),
#   ('course', 1),
#   ('imagery', 1)],
#  'A_Kinder_Eye': [('album', 4),
#   ('level', 2),
#   ('studio', 2),
#   ('musical', 1),
#   ('label', 1),
#   ('group', 1),
#   ('ninth', 1),
#   ('abbey', 0),
#   ('player', 0),
#   ('pollution', 0),
#   ('polish', 0),
#   ('police', 0),
#   ('poco', 0),
#   ('pleasure', 0),
#   ('platinum', 0),
#   ('play', 0),
#   ('place', 0),
#   ('pipe', 0),
#   ('pink', 0),
#   ('piggy', 0),
#   ('pierrot', 0),
#   ('pier', 0),
#   ('piece', 0),
#   ('pop', 0),
#   ('popular', 0),
#   ('pope', 0),
#   ('pianist', 0),
#   ('prince', 0),
#   ('primarily', 0),
#   ('previously', 0)],
#  'A_Little_Bit_Longer_(song)': [('song', 2),
#   ('sung', 1),
#   ('written', 1),
#   ('nick', 1),
#   ('little', 1),
#   ('album', 1),
#   ('promotional', 1),
#   ('studio', 1),
#   ('longer', 1),
#   ('bit', 1),
#   ('single', 1),
#   ('pipe', 0),
#   ('place', 0),
#   ('polish', 0),
#   ('platinum', 0),
#   ('play', 0),
#   ('player', 0),
#   ('pink', 0),
#   ('piggy', 0),
#   ('pleasure', 0),
#   ('pierrot', 0),
#   ('pier', 0),
#   ('poco', 0),
#   ('police', 0),
#   ('pope', 0),
#   ('pollution', 0),
#   ('pop', 0),
#   ('previously', 0),
#   ('previous', 0),
#   ('pretty', 0)],
#  'A_Love_That_Will_Never_Grow_Old': [('song', 5),
#   ('award', 4),
#   ('film', 3),
#   ('original', 3),
#   ('best', 3),
#   ('movie', 2),
#   ('owing', 1),
#   ('ineligible', 1),
#   ('grow', 1),
#   ('air', 1),
#   ('mountain', 1),
#   ('available', 1),
#   ('nominated', 1),
#   ('love', 1),
#   ('old', 1),
#   ('music', 1),
#   ('satellite', 1),
#   ('insufficient', 1),
#   ('consideration', 1),
#   ('argentine', 1),
#   ('won', 1),
#   ('time', 1),
#   ('composer', 1),
#   ('composed', 1),
#   ('controversially', 1),
#   ('globe', 1),
#   ('singer', 1),
#   ('directly', 1),
#   ('world', 1),
#   ('written', 1)],
#  'A_Man_Without_Love_(Kenneth_McKellar_song)': [('man', 6),
#   ('love', 5),
#   ('song', 2),
#   ('contest', 1),
#   ('ballad', 1),
#   ('entry', 1),
#   ('life', 1),
#   ('half', 1),
#   ('police', 0),
#   ('pope', 0),
#   ('pop', 0),
#   ('pollution', 0),
#   ('polish', 0),
#   ('abbey', 0),
#   ('poco', 0),
#   ('popularity', 0),
#   ('pleasure', 0),
#   ('player', 0),
#   ('play', 0),
#   ('platinum', 0),
#   ('place', 0),
#   ('pipe', 0),
#   ('pink', 0),
#   ('popular', 0),
#   ('posse', 0),
#   ('positive', 0),
#   ('present', 0),
#   ('prism', 0),
#   ('prior', 0),
#   ('prince', 0)]}

# %%
# Print the top 15 words said by each comedian
for song, top_words in top_dict.items():
    print(song)
    print(', '.join([word for word, count in top_words[0:14]]))
    print('---')
# Out:
# '97_Bonnie_&_Clyde
# song, shady, slim, kim, daughter, dark, throw, pier, sea, seat, dada, whilst, covered, rapper
# ---
# 'Cuz_I_Can_(Pink_song)
# album, song, dead, pink, single, written, martin, promotional, fourth, abbey, pollution, polish, police, poco
# ---
# 'Round_Midnight_(song)
# jazz, midnight, variety, pianist, quintet, hall, quickly, wide, standard, monk, musician, fame, version, added
# ---
# 'S_Wonderful
# song, especially, broadway, stage, jazz, standard, frank, popular, composed, musical, written, funny, year, considered
# ---
# 'The_Half_of_It,_Dearie'_Blues
# lady, musical, good, song, half, dearie, blues, composed, piggy, pink, pipe, place, pop, play
# ---
# 'Till_I_Collapse
# rapper, song, album, chart, fourth, hook, despite, track, billion, numerous, collapse, studio, till, single
# ---
# 'Tis_Harry_I'm_Plannin'_to_Marry
# song, sung, film, garter, sammy, jane, finally, near, times, end, musical, brown, marry, music
# ---
# 'n_Beetje
# song, dutch, faithful, bit, contest, little, previous, pronunciation, poco, close, unusual, preceding, television, following
# ---
# 't_Is_Genoeg
# song, sung, contest, entry, lover, love, night, normally, perspective, happiness, en, relationship, woman, pronounced
# ---
# 't_Is_OK
# song, dutch, contest, harmony, entry, happy, field, eleventh, following, received, brighten, jean, number, night
# ---
# (At_Your_Best)_You_Are_Love
# originally, hit, best, song, radio, mother, love, pipe, place, platinum, play, pope, pink, player
# ---
# (Drop_Dead)_Beautiful
# album, singles, brazil, second, peaked, united, seventh, fourth, billboard, criminal, tour, consecutive, music, successful
# ---
# (Evening)_Time_to_Get_Away
# time, album, original, away, song, lodge, days, future, entire, evening, afternoon, track, day, bridge
# ---
# (Every_Time_I_Turn_Around)_Back_in_Love_Again
# number, love, hit, spent, song, pop, singles, chart, gold, time, record, album, billboard, peaking
# ---
# (Everybody's_Waitin'_for)_The_Man_with_the_Bag
# kay, man, popular, dudley, song, bag, husband, regularly, television, people, early, list, reference, credit
# ---
# (Ghost)_Riders_in_the_Sky:_A_Cowboy_Legend
# ghost, song, sky, legend, cowboy, title, written, western, chose, television, pop, number, code, film
# ---
# (I'd_Like_to_Get_You_on_a)_Slow_Boat_to_China
# song, album, frank, dove, rosemary, biggest, bing, honor, ford, slow, meeting, china, version, popular
# ---
# (I'll_Be_with_You)_In_Apple_Blossom_Time
# song, ill, blossom, popular, time, apple, lyricist, written, play, police, poco, pleasure, player, pipe
# ---
# (I'm_Not_Your)_Steppin'_Stone
# major, song, cut, rock, hart, bobby, simple, tommy, musically, chord, bridge, album, verse, stone
# ---
# (I_Can't_Make_It)_Another_Day
# day, song, album, leak, track, make, later, unofficially, version, music, initially, times, posthumous, artist
# ---
# (I_Love_You)_For_Sentimental_Reasons
# song, best, member, founding, brown, music, vocalist, pat, company, list, popular, manor, group, ivory
# ---
# (If_You_Can't_Sing_It)_You'll_Have_to_Swing_It_(Mr._Paganini)
# song, cole, tribute, lady, sam, live, album, mark, birthday, associated, springboard, love, fixture, firm
# ---
# (Love_Is)_The_Tender_Trap
# song, film, love, trap, frank, tender, united, peaking, award, popular, major, hit, version, separately
# ---
# (Mama)_He_Treats_Your_Daughter_Mean
# chart, pop, brown, song, mean, lance, ruth, hit, billboard, written, number, record, daughter, polish
# ---
# (She's_So)_Selfish
# inspired, single, knack, compilation, selfish, debut, release, album, scatological, hit, number, song, woman, live
# ---
# (The_Same_Thing_Happens_with)_The_Birds_and_the_Bees
# film, lady, bees, screwball, starring, remake, story, eve, designed, comedy, head, written, based, directed
# ---
# (What's_So_Funny_'Bout)_Peace,_Love,_and_Understanding
# song, schwarz, album, single, version, new, nick, peace, great, popularity, whats, cover, included, covered
# ---
# (What_Is)_Love%3F
# abbey, process, pop, pollution, polish, police, poco, pleasure, player, play, platinum, place, pipe, pink
# ---
# 1+1_(song)
# music, idol, ballad, love, video, hot, performance, positive, soul, chart, concert, studio, different, power
# ---
# 100%25_(Mariah_Carey_song)
# abbey, process, pop, pollution, polish, police, poco, pleasure, player, play, platinum, place, pipe, pink
# ---
# 100%25_d'amour
# abbey, process, pop, pollution, polish, police, poco, pleasure, player, play, platinum, place, pipe, pink
# ---
# 100%25_te_ljubam
# abbey, process, pop, pollution, polish, police, poco, pleasure, player, play, platinum, place, pipe, pink
# ---
# 100_Years_Ago
# head, soup, featured, ago, song, rolling, album, rock, band, platinum, place, play, pop, player
# ---
# 10:15_Saturday_Night
# track, song, album, cure, single, imaginary, live, band, massive, night, attention, attack, included, area
# ---
# 11_(song)
# song, pope, frame, chapman, debut, production, divorce, solo, handled, huff, story, album, polish, police
# ---
# 12-Bar_Original
# song, instrumental, music, version, flying, tour, original, abbey, cover, shadow, single, commercially, startling, cayenne
# ---
# 13th_August_(instrumental)
# progressive, successful, help, bring, early, briefly, guitarist, splash, title, sound, instrumental, player, keyboard, music
# ---
# 14_Years
# illusion, rock, use, song, album, band, originally, organ, popular, pope, pop, pollution, polish, police
# ---
# 157_Riverside_Avenue
# live, song, version, length, album, band, included, lead, guitar, piano, stayed, make, way, time
# ---
# 1762_leto
# song, band, popular, science, include, place, ecumenical, st, alternative, folklore, nineteenth, folk, anniversary, magazine
# ---
# 17_(Avril_Lavigne_song)
# album, music, reaching, number, fifth, industrial, release, single, epic, week, japan, rock, tour, selling
# ---
# 18_(One_Direction_song)
# album, band, united, music, number, direction, eleventh, tenth, positive, march, scoring, international, malik, debut
# ---
# 192_(song)
# version, song, police, included, title, singer, read, second, telephone, north, album, number, poco, pleasure
# ---
# 1983..._(A_Merman_I_Should_Turn_to_Be)
# song, band, duration, album, chile, group, traffic, wood, second, track, flute, player, turn, voodoo
# ---
# 1987_(song)
# song, best, martin, video, category, musician, space, music, collective, astronaut, alternative, nominated, album, live
# ---
# 1998_(instrumental)
# music, armada, peaked, package, binary, delicious, track, anniversary, remix, title, year, morph, numerous, instrumental
# ---
# 1_Life_(Xandee_song)
# song, contest, close, representative, semifinal, received, following, stage, number, thirteenth, sandy, grand, advantage, entry
# ---
# 1_Train_(song)
# song, album, produced, high, release, bubbling, brown, joey, debut, recording, cut, artist, hip, long
# ---
# 2112_(song)
# song, album, live, section, combined, syrinx, used, step, pronounced, starting, test, echo, long, comic
# ---
# 2120_South_Michigan_Avenue
# title, track, second, song, south, version, michigan, riff, credit, sound, composition, rolling, original, band
# ---
# 21st_Century_Schizoid_Man
# crimson, king, progressive, rock, schizoid, century, album, song, debut, man, band, court, pleasure, poco
# ---
# 23_Minutes_Over_Brussels
# recording, debut, heyday, performance, release, duo, indication, june, clash, supporting, reaction, album, live, largely
# ---
# 24's_(RichGirl_song)
# song, group, multiple, hot, rapper, times, child, album, debut, peak, number, pronounced, bun, promotional
# ---
# 24_Hrs._to_Live
# radio, version, album, brown, pen, foxy, kim, song, queen, solely, female, lox, fell, cut
# ---
# 25_Minutes_to_Go
# album, inside, folk, song, play, polish, police, poco, pleasure, player, abbey, pianist, platinum, place
# ---
# 2HB
# music, bogart, song, roxy, album, ferry, piano, featured, effects, melody, tape, dedication, time, version
# ---
# 2_Long_(Andrzej_Piaseczny_song)
# contest, polish, song, entry, following, did, wearing, country, brown, number, include, man, taking, wer
# ---
# 2_Rights_Make_1_Wrong
# album, band, produced, york, rev, action, rock, new, studio, player, pop, pollution, polish, police
# ---
# 3-Minute_Rule
# track, beastie, written, group, hip, album, hop, dust, rule, produced, place, pipe, platinum, pollution
# ---
# 3.6.5
# album, singles, chart, debut, growl, music, million, june, edition, went, entering, entertainment, august, version
# ---
# 300_M.P.H._Torrential_Outpour_Blues
# blues, song, white, unexpected, post, shuffle, fading, country, use, screeching, violently, mark, quiet, warning
# ---
# 32_Flavors
# song, featured, number, ad, football, romantic, national, variation, album, slogan, covered, debut, better, cream
# ---
# 34_(song)
# song, band, track, album, table, number, pay, percussionist, piece, hepatitis, debut, collaborator, hidden, studio
# ---
# 40,000_Headmen
# song, album, traffic, blood, sweat, music, tour, box, protagonist, version, mason, dream, dreamlike, fact
# ---
# 41_(song)
# album, band, song, featured, crash, pleasure, pop, pollution, polish, police, poco, abbey, popular, player
# ---
# 42_(song)
# song, band, album, live, rock, fourth, ballad, version, featured, viva, solo, arrangement, finally, chorus
# ---
# 4_Carats
# number, song, album, holiday, wrapped, artist, chart, ending, digital, release, pop, week, written, red
# ---
# 4_the_Tears_in_Your_Eyes
# album, live, rock, track, song, world, title, famine, included, relief, band, turner, trapped, bass
# ---
# 4st_7lb
# band, rock, alternative, song, album, manic, street, holy, welsh, pollution, polish, police, poco, prince
# ---
# 4th_Time_Around
# blonde, song, bob, time, album, place, police, poco, pleasure, player, play, platinum, pipe, pollution
# ---
# 4th_of_July_(U2_song)
# band, track, song, live, bassist, concert, unbeknownst, sixth, instrumental, play, edge, ambient, san, guitarist
# ---
# 4x4_(song)
# cyrus, album, video, music, record, single, career, pop, fourth, musical, billboard, montana, later, million
# ---
# 5-10-15_Hours
# brown, induction, hall, best, ruth, roll, work, fame, said, rock, song, sides, written, wrote
# ---
# 5/4_(Gorillaz_song)
# band, song, track, tour, rise, taking, clint, celebrity, subsequently, switch, time, brought, signature, title
# ---
# 53rd_&_3rd
# rock, punk, band, song, play, pollution, polish, police, poco, pleasure, player, abbey, pope, platinum
# ---
# 5:15_(Bridgit_Mendler_song)
# song, chart, mad, music, number, debut, influence, album, recording, received, artist, country, instrumental, hello
# ---
# 7_O'Clock_News/Silent_Night
# oclock, night, summer, track, duo, sage, album, silent, collage, song, music, sound, rendition, thyme
# ---
# 7_Skies_H3
# composition, experimental, skies, rock, flaming, band, piggy, pleasure, pope, pop, pollution, polish, police, poco
# ---
# 7th_Wonder
# song, contest, seventh, singing, time, wonder, close, following, happy, man, scored, entry, waiting, marcel
# ---
# 9AM_in_Dallas
# album, track, rapper, song, june, version, release, debut, number, included, billboard, later, eventual, days
# ---
# A-Ba-Ni-Bi
# song, language, game, winning, word, meaning, script, contest, abbey, pollution, polish, police, poco, pleasure
# ---
# A.D.H.D_(Kendrick_Lamar_song)
# song, producer, studio, collaborator, rapper, album, debut, produced, frequent, overture, poco, pope, pop, pollution
# ---
# AOV_(song)
# single, song, album, major, violence, promotional, metal, sixth, slipknot, band, heavy, fifth, chapter, gray
# ---
# A_Beginning
# beginning, song, martin, real, night, anthology, piece, new, introduction, cue, film, scored, intended, instrumental
# ---
# A_Blossom_Fell
# king, cole, billboard, blossom, nat, song, fell, sides, note, chart, version, combined, era, combination
# ---
# A_Case_of_You
# album, case, blue, song, pollution, polish, police, poco, pleasure, player, play, abbey, pope, platinum
# ---
# A_Century_of_Love
# song, final, contest, geta, century, time, love, received, san, night, entry, history, following, semifinal
# ---
# A_Cottage_for_Sale
# song, cottage, sale, composed, new, popular, music, march, orchestra, larry, yorker, written, pope, pop
# ---
# A_Criminal_Mind
# gowan, animal, strange, mind, single, second, artist, song, criminal, album, number, signature, canada, studio
# ---
# A_Day_in_the_Life
# song, mainly, chord, inspired, band, middle, day, death, second, deep, smoking, segment, crescendo, creation
# ---
# A_Day_in_the_Life_of_a_Tree
# band, song, environmental, pollution, album, tree, life, vocal, day, manager, rock, inspired, written, jack
# ---
# A_Fellow_Needs_a_Girl
# broadway, musical, work, allegro, sought, cast, large, play, stage, production, end, tour, run, music
# ---
# A_Great_Day_for_Freedom
# bell, album, great, pink, division, day, freedom, song, pope, pop, pollution, polish, police, abbey
# ---
# A_Guy_Is_a_Guy
# song, knave, version, chart, guy, based, march, brand, bridal, dating, chorus, number, widely, june
# ---
# A_Guy_Like_You
# song, stage, german, like, hunchback, production, console, try, version, featured, musical, dame, guy, flight
# ---
# A_Hard_Rain's_a-Gonna_Fall
# song, evil, feeling, bob, symbolist, saying, inspiration, culture, new, common, schism, public, days, taken
# ---
# A_Kinder_Eye
# album, level, studio, musical, label, group, ninth, abbey, player, pollution, polish, police, poco, pleasure
# ---
# A_Little_Bit_Longer_(song)
# song, sung, written, nick, little, album, promotional, studio, longer, bit, single, pipe, place, polish
# ---
# A_Love_That_Will_Never_Grow_Old
# song, award, film, original, best, movie, owing, ineligible, grow, air, mountain, available, nominated, love
# ---
# A_Man_Without_Love_(Kenneth_McKellar_song)
# man, love, song, contest, ballad, entry, life, half, police, pope, pop, pollution, polish, abbey
# ---

# %%
# Let's first pull out the top 30 words for each comedian
words = []
for song in data.columns:
    top = [word for (word, count) in top_dict[song]]
    for t in top:
        words.append(t)
        
Counter(words).most_common()
# Out:
# [('song', 82),
#  ('album', 59),
#  ('play', 55),
#  ('platinum', 53),
#  ('place', 52),
#  ('player', 51),
#  ('pleasure', 49),
#  ('pipe', 49),
#  ('poco', 47),
#  ('polish', 43),
#  ('police', 43),
#  ('pink', 42),
#  ('pollution', 41),
#  ('pop', 41),
#  ('popular', 41),
#  ('piggy', 39),
#  ('pope', 32),
#  ('written', 30),
#  ('band', 29),
#  ('pierrot', 27),
#  ('previously', 27),
#  ('previous', 26),
#  ('abbey', 25),
#  ('number', 24),
#  ('music', 23),
#  ('primarily', 22),
#  ('pretty', 22),
#  ('popularity', 22),
#  ('pier', 21),
#  ('prince', 21),
#  ('version', 21),
#  ('studio', 19),
#  ('single', 18),
#  ('track', 18),
#  ('debut', 18),
#  ('time', 16),
#  ('rock', 16),
#  ('positive', 15),
#  ('piece', 15),
#  ('present', 14),
#  ('live', 13),
#  ('prior', 13),
#  ('composed', 12),
#  ('chart', 12),
#  ('featured', 12),
#  ('love', 12),
#  ('title', 12),
#  ('prelude', 11),
#  ('posse', 11),
#  ('night', 10),
#  ('included', 9),
#  ('contest', 9),
#  ('billboard', 9),
#  ('tour', 9),
#  ('later', 9),
#  ('recording', 9),
#  ('piano', 9),
#  ('produced', 9),
#  ('musical', 8),
#  ('film', 8),
#  ('preceding', 8),
#  ('second', 8),
#  ('received', 8),
#  ('release', 8),
#  ('instrumental', 8),
#  ('fourth', 7),
#  ('predominantly', 7),
#  ('brown', 7),
#  ('hit', 7),
#  ('following', 7),
#  ('entry', 7),
#  ('original', 7),
#  ('originally', 7),
#  ('best', 7),
#  ('hot', 7),
#  ('day', 7),
#  ('solo', 7),
#  ('rapper', 6),
#  ('promotional', 6),
#  ('power', 6),
#  ('close', 6),
#  ('group', 6),
#  ('singles', 6),
#  ('united', 6),
#  ('peaking', 6),
#  ('lead', 6),
#  ('man', 6),
#  ('did', 6),
#  ('new', 6),
#  ('process', 6),
#  ('covered', 5),
#  ('successful', 5),
#  ('times', 5),
#  ('voting', 5),
#  ('singer', 5),
#  ('record', 5),
#  ('artist', 5),
#  ('june', 5),
#  ('production', 5),
#  ('sound', 5),
#  ('overture', 5),
#  ('taking', 4),
#  ('pianist', 4),
#  ('composition', 4),
#  ('stage', 4),
#  ('year', 4),
#  ('blues', 4),
#  ('sung', 4),
#  ('end', 4),
#  ('peace', 4),
#  ('television', 4),
#  ('field', 4),
#  ('fifth', 4),
#  ('make', 4),
#  ('radio', 4),
#  ('peaked', 4),
#  ('days', 4),
#  ('minute', 4),
#  ('major', 4),
#  ('company', 4),
#  ('cut', 4),
#  ('final', 4),
#  ('mark', 4),
#  ('inspired', 4),
#  ('cover', 4),
#  ('video', 4),
#  ('used', 4),
#  ('guitarist', 4),
#  ('prism', 4),
#  ('guitar', 4),
#  ('march', 4),
#  ('country', 4),
#  ('sixth', 4),
#  ('life', 4),
#  ('south', 4),
#  ('baby', 3),
#  ('little', 3),
#  ('martin', 3),
#  ('standard', 3),
#  ('posthumously', 3),
#  ('frank', 3),
#  ('lady', 3),
#  ('good', 3),
#  ('half', 3),
#  ('despite', 3),
#  ('dutch', 3),
#  ('lover', 3),
#  ('said', 3),
#  ('sang', 3),
#  ('pronounced', 3),
#  ('outlook', 3),
#  ('singing', 3),
#  ('sing', 3),
#  ('style', 3),
#  ('turn', 3),
#  ('list', 3),
#  ('took', 3),
#  ('post', 3),
#  ('initially', 3),
#  ('king', 3),
#  ('label', 3),
#  ('signature', 3),
#  ('concert', 3),
#  ('award', 3),
#  ('nominated', 3),
#  ('intended', 3),
#  ('story', 3),
#  ('based', 3),
#  ('ballad', 3),
#  ('heavy', 3),
#  ('black', 3),
#  ('bass', 3),
#  ('alternative', 3),
#  ('folk', 3),
#  ('national', 3),
#  ('praising', 3),
#  ('international', 3),
#  ('won', 3),
#  ('producer', 3),
#  ('taken', 3),
#  ('real', 3),
#  ('kim', 2),
#  ('daughter', 2),
#  ('strange', 2),
#  ('like', 2),
#  ('let', 2),
#  ('jazz', 2),
#  ('midnight', 2),
#  ('hall', 2),
#  ('musician', 2),
#  ('fame', 2),
#  ('especially', 2),
#  ('broadway', 2),
#  ('funny', 2),
#  ('face', 2),
#  ('numerous', 2),
#  ('till', 2),
#  ('sammy', 2),
#  ('finally', 2),
#  ('bit', 2),
#  ('perspective', 2),
#  ('victory', 2),
#  ('woman', 2),
#  ('does', 2),
#  ('happy', 2),
#  ('eleventh', 2),
#  ('winning', 2),
#  ('seventh', 2),
#  ('criminal', 2),
#  ('canada', 2),
#  ('certified', 2),
#  ('generally', 2),
#  ('starring', 2),
#  ('musically', 2),
#  ('evening', 2),
#  ('bridge', 2),
#  ('classic', 2),
#  ('home', 2),
#  ('biggest', 2),
#  ('fall', 2),
#  ('posthumous', 2),
#  ('early', 2),
#  ('credit', 2),
#  ('club', 2),
#  ('brought', 2),
#  ('actor', 2),
#  ('rosemary', 2),
#  ('china', 2),
#  ('jimmy', 2),
#  ('barry', 2),
#  ('blossom', 2),
#  ('chord', 2),
#  ('collaboration', 2),
#  ('entertainment', 2),
#  ('member', 2),
#  ('vocalist', 2),
#  ('creation', 2),
#  ('wrote', 2),
#  ('cole', 2),
#  ('ruth', 2),
#  ('comedy', 2),
#  ('head', 2),
#  ('directed', 2),
#  ('nick', 2),
#  ('great', 2),
#  ('performance', 2),
#  ('soul', 2),
#  ('different', 2),
#  ('instrumentation', 2),
#  ('rolling', 2),
#  ('table', 2),
#  ('opening', 2),
#  ('booklet', 2),
#  ('anthology', 2),
#  ('length', 2),
#  ('progressive', 2),
#  ('short', 2),
#  ('bassist', 2),
#  ('known', 2),
#  ('use', 2),
#  ('roll', 2),
#  ('introduction', 2),
#  ('include', 2),
#  ('anniversary', 2),
#  ('magazine', 2),
#  ('wedding', 2),
#  ('week', 2),
#  ('boy', 2),
#  ('sold', 2),
#  ('status', 2),
#  ('north', 2),
#  ('traffic', 2),
#  ('electric', 2),
#  ('semifinal', 2),
#  ('hip', 2),
#  ('long', 2),
#  ('hop', 2),
#  ('combined', 2),
#  ('better', 2),
#  ('fading', 2),
#  ('unreleased', 2),
#  ('century', 2),
#  ('duo', 2),
#  ('suicide', 2),
#  ('girl', 2),
#  ('female', 2),
#  ('fell', 2),
#  ('urban', 2),
#  ('resulting', 2),
#  ('blue', 2),
#  ('million', 2),
#  ('went', 2),
#  ('august', 2),
#  ('white', 2),
#  ('jack', 2),
#  ('switch', 2),
#  ('past', 2),
#  ('movie', 2),
#  ('store', 2),
#  ('collaborator', 2),
#  ('response', 2),
#  ('restrict', 2),
#  ('result', 2),
#  ('box', 2),
#  ('chorus', 2),
#  ('death', 2),
#  ('world', 2),
#  ('street', 2),
#  ('rendition', 2),
#  ('bob', 2),
#  ('san', 2),
#  ('public', 2),
#  ('vocal', 2),
#  ('work', 2),
#  ('sides', 2),
#  ('instead', 2),
#  ('making', 2),
#  ('parsley', 2),
#  ('scored', 2),
#  ('overall', 2),
#  ('sale', 2),
#  ('guy', 2),
#  ('owing', 2),
#  ('shady', 1),
#  ('slim', 1),
#  ('dark', 1),
#  ('throw', 1),
#  ('sea', 1),
#  ('seat', 1),
#  ('dada', 1),
#  ('whilst', 1),
#  ('wife', 1),
#  ('couple', 1),
#  ('just', 1),
#  ('fashion', 1),
#  ('ex', 1),
#  ('undertone', 1),
#  ('going', 1),
#  ('car', 1),
#  ('strap', 1),
#  ('dead', 1),
#  ('variety', 1),
#  ('quintet', 1),
#  ('quickly', 1),
#  ('wide', 1),
#  ('monk', 1),
#  ('added', 1),
#  ('round', 1),
#  ('considered', 1),
#  ('wonderful', 1),
#  ('dearie', 1),
#  ('hook', 1),
#  ('billion', 1),
#  ('collapse', 1),
#  ('garter', 1),
#  ('jane', 1),
#  ('near', 1),
#  ('marry', 1),
#  ('fain', 1),
#  ('character', 1),
#  ('harry', 1),
#  ('golden', 1),
#  ('dressing', 1),
#  ('partly', 1),
#  ('calamity', 1),
#  ('pair', 1),
#  ('faithful', 1),
#  ('pronunciation', 1),
#  ('unusual', 1),
#  ('ami', 1),
#  ('wat', 1),
#  ('entirely', 1),
#  ('normally', 1),
#  ('happiness', 1),
#  ('en', 1),
#  ('relationship', 1),
#  ('het', 1),
#  ('filippo', 1),
#  ('belong', 1),
#  ('unfaithful', 1),
#  ('infidelity', 1),
#  ('harmony', 1),
#  ('brighten', 1),
#  ('jean', 1),
#  ('eddy', 1),
#  ('colorado', 1),
#  ('vie', 1),
#  ('chanter', 1),
#  ('trio', 1),
#  ('minimal', 1),
#  ('mother', 1),
#  ('brazil', 1),
#  ('consecutive', 1),
#  ('circus', 1),
#  ('orbit', 1),
#  ('leg', 1),
#  ('hold', 1),
#  ('travis', 1),
#  ('away', 1),
#  ('lodge', 1),
#  ('future', 1),
#  ('entire', 1),
#  ('afternoon', 1),
#  ('forever', 1),
#  ('hayward', 1),
#  ('master', 1),
#  ('satin', 1),
#  ('nights', 1),
#  ('excerpt', 1),
#  ('unlisted', 1),
#  ('spent', 1),
#  ('gold', 1),
#  ('grey', 1),
#  ('kay', 1),
#  ('dudley', 1),
#  ('bag', 1),
#  ('husband', 1),
#  ('regularly', 1),
#  ('people', 1),
#  ('reference', 1),
#  ('special', 1),
#  ('extra', 1),
#  ('sleigh', 1),
#  ('ghost', 1),
#  ('sky', 1),
#  ('legend', 1),
#  ('cowboy', 1),
#  ('western', 1),
#  ('chose', 1),
#  ('code', 1),
#  ('crossover', 1),
#  ('dove', 1),
#  ('bing', 1),
#  ('honor', 1),
#  ('ford', 1),
#  ('slow', 1),
#  ('meeting', 1),
#  ('episode', 1),
#  ('songbook', 1),
#  ('official', 1),
#  ('boat', 1),
#  ('duet', 1),
#  ('domino', 1),
#  ('ill', 1),
#  ('apple', 1),
#  ('lyricist', 1),
#  ('hart', 1),
#  ('bobby', 1),
#  ('simple', 1),
#  ('tommy', 1),
#  ('verse', 1),
#  ('stone', 1),
#  ('revere', 1),
#  ('ride', 1),
#  ('progression', 1),
#  ('leak', 1),
#  ('unofficially', 1),
#  ('storm', 1),
#  ('stated', 1),
#  ('snippet', 1),
#  ('removing', 1),
#  ('founding', 1),
#  ('pat', 1),
#  ('manor', 1),
#  ('ivory', 1),
#  ('joe', 1),
#  ('quartet', 1),
#  ('ink', 1),
#  ('autobiography', 1),
#  ('late', 1),
#  ('sentimental', 1),
#  ('respectively', 1),
#  ('tribute', 1),
#  ('sam', 1),
#  ('birthday', 1),
#  ('associated', 1),
#  ('springboard', 1),
#  ('fixture', 1),
#  ('firm', 1),
#  ('scat', 1),
#  ('providing', 1),
#  ('chaka', 1),
#  ('strongly', 1),
#  ('swing', 1),
#  ('trap', 1),
#  ('tender', 1),
#  ('separately', 1),
#  ('lost', 1),
#  ('thing', 1),
#  ('van', 1),
#  ('kingdom', 1),
#  ('academy', 1),
#  ('mean', 1),
#  ('lance', 1),
#  ('knack', 1),
#  ('compilation', 1),
#  ('selfish', 1),
#  ('scatological', 1),
#  ('nastiness', 1),
#  ('bees', 1),
#  ('screwball', 1),
#  ('remake', 1),
#  ('eve', 1),
#  ('designed', 1),
#  ('schwarz', 1),
#  ('whats', 1),
#  ('famously', 1),
#  ('squirm', 1),
#  ('understanding', 1),
#  ('bout', 1),
#  ('armed', 1),
#  ('saw', 1),
#  ('idol', 1),
#  ('reception', 1),
#  ('clip', 1),
#  ('camera', 1),
#  ('innovative', 1),
#  ('dance', 1),
#  ('considerable', 1),
#  ('soup', 1),
#  ('ago', 1),
#  ('cure', 1),
#  ('imaginary', 1),
#  ('massive', 1),
#  ('attention', 1),
#  ('attack', 1),
#  ('area', 1),
#  ('watching', 1),
#  ('tap', 1),
#  ('smith', 1),
#  ('newly', 1),
#  ('utterly', 1),
#  ('mezzanine', 1),
#  ('fiction', 1),
#  ('frame', 1),
#  ('chapman', 1),
#  ('divorce', 1),
#  ('handled', 1),
#  ('huff', 1),
#  ('flying', 1),
#  ('shadow', 1),
#  ('commercially', 1),
#  ('startling', 1),
#  ('cayenne', 1),
#  ('book', 1),
#  ('recall', 1),
#  ('told', 1),
#  ('unissued', 1),
#  ('bar', 1),
#  ('dig', 1),
#  ('quote', 1),
#  ('help', 1),
#  ('bring', 1),
#  ('briefly', 1),
#  ('splash', 1),
#  ('keyboard', 1),
#  ('express', 1),
#  ('compose', 1),
#  ('drummer', 1),
#  ('central', 1),
#  ('illusion', 1),
#  ('organ', 1),
#  ('stayed', 1),
#  ('way', 1),
#  ('extended', 1),
#  ('arch', 1),
#  ('decade', 1),
#  ('neal', 1),
#  ('interlude', 1),
#  ('science', 1),
#  ('ecumenical', 1),
#  ('st', 1),
#  ('folklore', 1),
#  ('nineteenth', 1),
#  ('archbishop', 1),
#  ('archbishopric', 1),
#  ('collection', 1),
#  ('periodical', 1),
#  ('movement', 1),
#  ('shortly', 1),
#  ('departure', 1),
#  ('reaching', 1),
#  ('industrial', 1),
#  ('epic', 1),
#  ('japan', 1),
#  ('selling', 1),
#  ('contain', 1),
#  ('controversial', 1),
#  ('moderately', 1),
#  ('impacted', 1),
#  ('promote', 1),
#  ('unnatural', 1),
#  ('direction', 1),
#  ('tenth', 1),
#  ('scoring', 1),
#  ('malik', 1),
#  ('federation', 1),
#  ('industry', 1),
#  ('phonographic', 1),
#  ('steal', 1),
#  ('leaving', 1),
#  ('according', 1),
#  ('read', 1),
#  ('telephone', 1),
#  ('duration', 1),
#  ('chile', 1),
#  ('wood', 1),
#  ('flute', 1),
#  ('voodoo', 1),
#  ('merman', 1),
#  ('experience', 1),
#  ('category', 1),
#  ('space', 1),
#  ('collective', 1),
#  ('astronaut', 1),
#  ('usually', 1),
#  ('shown', 1),
#  ('led', 1),
#  ('campo', 1),
#  ('armada', 1),
#  ('package', 1),
#  ('binary', 1),
#  ('delicious', 1),
#  ('remix', 1),
#  ('morph', 1),
#  ('trance', 1),
#  ('jordan', 1),
#  ('sell', 1),
#  ('kissy', 1),
#  ('representative', 1),
#  ('thirteenth', 1),
#  ('sandy', 1),
#  ('grand', 1),
#  ('advantage', 1),
#  ('believe', 1),
#  ('compete', 1),
#  ('opportunity', 1),
#  ('need', 1),
#  ('high', 1),
#  ('bubbling', 1),
#  ('joey', 1),
#  ('fellow', 1),
#  ('train', 1),
#  ('feel', 1),
#  ('big', 1),
#  ('underground', 1),
#  ('additional', 1),
#  ('rocky', 1),
#  ('section', 1),
#  ('syrinx', 1),
#  ('step', 1),
#  ('starting', 1),
#  ('test', 1),
#  ('echo', 1),
#  ('comic', 1),
#  ('rush', 1),
#  ('suite', 1),
#  ('library', 1),
#  ('michigan', 1),
#  ('riff', 1),
#  ('avenue', 1),
#  ('listed', 1),
#  ('chess', 1),
#  ('tremolo', 1),
#  ('crimson', 1),
#  ('schizoid', 1),
#  ('court', 1),
#  ('heyday', 1),
#  ('indication', 1),
#  ('clash', 1),
#  ('supporting', 1),
#  ('reaction', 1),
#  ('largely', 1),
#  ('unheard', 1),
#  ('reissue', 1),
#  ('multiple', 1),
#  ('child', 1),
#  ('peak', 1),
#  ('bun', 1),
#  ('rich', 1),
#  ('acclaim', 1),
#  ('critical', 1),
#  ('pen', 1),
#  ('foxy', 1),
#  ('queen', 1),
#  ('solely', 1),
#  ('lox', 1),
#  ('interview', 1),
#  ('project', 1),
#  ('frustration', 1),
#  ('cancellation', 1),
#  ('rob', 1),
#  ('inside', 1),
#  ('bogart', 1),
#  ('roxy', 1),
#  ('ferry', 1),
#  ('effects', 1),
#  ('melody', 1),
#  ('tape', 1),
#  ('dedication', 1),
#  ('star', 1),
#  ('stick', 1),
#  ('prominently', 1),
#  ('particular', 1),
#  ('dominated', 1),
#  ('sax', 1),
#  ('goes', 1),
#  ('wearing', 1),
#  ('wer', 1),
#  ('decision', 1),
#  ('eighteenth', 1),
#  ('energy', 1),
#  ('coat', 1),
#  ('backing', 1),
#  ('york', 1),
#  ('rev', 1),
#  ('action', 1),
#  ('beastie', 1),
#  ('dust', 1),
#  ('rule', 1),
#  ('growl', 1),
#  ('edition', 1),
#  ('entering', 1),
#  ('hug', 1),
#  ('wolf', 1),
#  ('distributed', 1),
#  ('unexpected', 1),
#  ('shuffle', 1),
#  ('screeching', 1),
#  ('violently', 1),
#  ('quiet', 1),
#  ('warning', 1),
#  ('really', 1),
#  ('moment', 1),
#  ('torrential', 1),
#  ('thump', 1),
#  ('nearly', 1),
#  ('break', 1),
#  ('ad', 1),
#  ('football', 1),
#  ('romantic', 1),
#  ('variation', 1),
#  ('slogan', 1),
#  ('cream', 1),
#  ('ani', 1),
#  ('ice', 1),
#  ('campaign', 1),
#  ('league', 1),
#  ('worn', 1),
#  ('pay', 1),
#  ('percussionist', 1),
#  ('hepatitis', 1),
#  ('hidden', 1),
#  ('blank', 1),
#  ('carter', 1),
#  ('blood', 1),
#  ('sweat', 1),
#  ('protagonist', 1),
#  ('mason', 1),
#  ('dream', 1),
#  ('dreamlike', 1),
#  ('fact', 1),
#  ('demigod', 1),
#  ('set', 1),
#  ('profane', 1),
#  ('faith', 1),
#  ('eponymous', 1),
#  ('foot', 1),
#  ('involvement', 1),
#  ('dear', 1),
#  ('crash', 1),
#  ('viva', 1),
#  ('arrangement', 1),
#  ('la', 1),
#  ('divided', 1),
#  ('passive', 1),
#  ('holiday', 1),
#  ('wrapped', 1),
#  ('ending', 1),
#  ('digital', 1),
#  ('red', 1),
#  ('ambivalent', 1),
#  ('lyrically', 1),
#  ('voluptuous', 1),
#  ('helmed', 1),
#  ('materialism', 1),
#  ('famine', 1),
#  ('relief', 1),
#  ('turner', 1),
#  ('trapped', 1),
#  ('topped', 1),
#  ('born', 1),
#  ('northern', 1),
#  ('obscure', 1),
#  ('charity', 1),
#  ('manic', 1),
#  ('holy', 1),
#  ('welsh', 1),
#  ('blonde', 1),
#  ('unbeknownst', 1),
#  ('edge', 1),
#  ('ambient', 1),
#  ('spontaneously', 1),
#  ('unforgettable', 1),
#  ('cyrus', 1),
#  ('career', 1),
#  ('montana', 1),
#  ('continued', 1),
#  ('guest', 1),
#  ('rami', 1),
#  ('provocative', 1),
#  ('beaten', 1),
#  ('ball', 1),
#  ('induction', 1),
#  ('rise', 1),
#  ('clint', 1),
#  ('celebrity', 1),
#  ('subsequently', 1),
#  ('biography', 1),
#  ('beth', 1),
#  ('virtual', 1),
#  ('ogre', 1),
#  ('follow', 1),
#  ('punk', 1),
#  ('mad', 1),
#  ('influence', 1),
#  ('hello', 1),
#  ('oclock', 1),
#  ('summer', 1),
#  ('sage', 1),
#  ('silent', 1),
#  ('collage', 1),
#  ('thyme', 1),
#  ('news', 1),
#  ('bulletin', 1),
#  ('carol', 1),
#  ('actual', 1),
#  ('replacement', 1),
#  ('experimental', 1),
#  ('skies', 1),
#  ('flaming', 1),
#  ('wonder', 1),
#  ('waiting', 1),
#  ('marcel', 1),
#  ('equal', 1),
#  ('spell', 1),
#  ('score', 1),
#  ('tell', 1),
#  ('finish', 1),
#  ('audience', 1),
#  ('join', 1),
#  ('twentieth', 1),
#  ('seven', 1),
#  ('eventual', 1),
#  ('thank', 1),
#  ('bonus', 1),
#  ('leading', 1),
#  ('strong', 1),
#  ('drake', 1),
#  ('language', 1),
#  ('game', 1),
#  ('word', 1),
#  ('meaning', 1),
#  ('script', 1),
#  ('frequent', 1),
#  ('originality', 1),
#  ('violence', 1),
#  ('metal', 1),
#  ('slipknot', 1),
#  ('chapter', 1),
#  ('gray', 1),
#  ('approaching', 1),
#  ('abbreviation', 1),
#  ('report', 1),
#  ('resurgence', 1),
#  ('beginning', 1),
#  ('cue', 1),
#  ('bird', 1),
#  ('incidental', 1),
#  ('right', 1),
#  ('double', 1),
#  ('yellow', 1),
#  ('nat', 1),
#  ('note', 1),
#  ('era', 1),
#  ('combination', 1),
#  ('data', 1),
#  ('case', 1),
#  ('geta', 1),
#  ('history', 1),
#  ('complice', 1),
#  ('failing', 1),
#  ('absent', 1),
#  ('cottage', 1),
#  ('orchestra', 1),
#  ('larry', 1),
#  ('yorker', 1),
#  ('gowan', 1),
#  ('animal', 1),
#  ('mind', 1),
#  ('mainly', 1),
#  ('middle', 1),
#  ('deep', 1),
#  ('smoking', 1),
#  ('segment', 1),
#  ('crescendo', 1),
#  ('riding', 1),
#  ('contemporary', 1),
#  ('class', 1),
#  ('reputed', 1),
#  ('sustained', 1),
#  ('bus', 1),
#  ('tara', 1),
#  ('broadcast', 1),
#  ('beck', 1),
#  ('environmental', 1),
#  ('tree', 1),
#  ('manager', 1),
#  ('beach', 1),
#  ('allegro', 1),
#  ('sought', 1),
#  ('cast', 1),
#  ('large', 1),
#  ('run', 1),
#  ('west', 1),
#  ('immense', 1),
#  ('moralistic', 1),
#  ('deal', 1),
#  ('ended', 1),
#  ('fortune', 1),
#  ('mille', 1),
#  ('rarely', 1),
#  ('props', 1),
#  ('haven', 1),
#  ('bell', 1),
#  ('division', 1),
#  ('freedom', 1),
#  ('knave', 1),
#  ('brand', 1),
#  ('bridal', 1),
#  ('dating', 1),
#  ('widely', 1),
#  ('juke', 1),
#  ('proof', 1),
#  ('slob', 1),
#  ('established', 1),
#  ('war', 1),
#  ('flip', 1),
#  ('alehouse', 1),
#  ('actually', 1),
#  ('german', 1),
#  ('hunchback', 1),
#  ('console', 1),
#  ('try', 1),
#  ('dame', 1),
#  ('flight', 1),
#  ('evil', 1),
#  ('feeling', 1),
#  ('symbolist', 1),
#  ('saying', 1),
#  ('inspiration', 1),
#  ('culture', 1),
#  ('common', 1),
#  ('schism', 1),
#  ('question', 1),
#  ('communicating', 1),
#  ('volume', 1),
#  ('warfare', 1),
#  ('answer', 1),
#  ('aware', 1),
#  ('missile', 1),
#  ('lyrical', 1),
#  ('memoir', 1),
#  ('traditional', 1),
#  ('human', 1),
#  ('course', 1),
#  ('imagery', 1),
#  ('level', 1),
#  ('ninth', 1),
#  ('longer', 1),
#  ('ineligible', 1),
#  ('grow', 1),
#  ('air', 1),
#  ('mountain', 1),
#  ('available', 1),
#  ('old', 1),
#  ('satellite', 1),
#  ('insufficient', 1),
#  ('consideration', 1),
#  ('argentine', 1),
#  ('composer', 1),
#  ('controversially', 1),
#  ('globe', 1),
#  ('directly', 1)]

# %% [markdown]
# ## After the first run
# When running the program for the first time, I saw many Russian/Swedish words, with letters the english alphabet doesn't include. So, the first step was for me to remove all the letters, that don't come up in the English alphabet. I did this by using the ascii letters and removing every non-ascii letter from the whole corpus. This stepremoved nearly all foreign letters from the text and left me with only the words with ascii symbols.

# %% [markdown]
# ## After the second run
# The second time running this command, I found out that most words that are at the top of the list, aren't actual English words such as "perry" "eminem", so my goal was to go back to my original data_clean program and add a function that would let me remove all the unnecessary words. The whole word count went from 2500+ words to now nearly 1300 words.
